# %%
import pandas as pd

# 導入數據 
train = pd.read_csv(r'C:/Users/Cindy/Desktop/train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#是否有缺失值
train.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#缺失值以中位數代替
train['Age'] = train['Age'].fillna(train['Age'].median())
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#分別按'Survived','Pclass','Sex','Age'大小排列
train = train.sort_values(by=['Survived','Pclass','Sex','Age','SibSp','Parch'])
train
# Out:
#      PassengerId  Survived  Pclass  \
# 297          298         0       1
# 498          499         0       1
# 177          178         0       1
# 505          506         0       1
# 748          749         0       1
# ..           ...       ...     ...
# 579          580         1       3
# 838          839         1       3
# 400          401         1       3
# 414          415         1       3
# 338          339         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 297                     Allison, Miss. Helen Loraine  female   2.0      1
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 505       Penasco y Castellana, Mr. Victor de Satode    male  18.0      1
# 748                        Marvin, Mr. Daniel Warner    male  19.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
#Sex為male，則傳回0，為female，則傳回1
train.loc[train['Sex'] =='male','Sex']=0
train.loc[train['Sex'] =='female','Sex']=1
train
# Out:
#      PassengerId  Survived  Pclass  \
# 297          298         0       1
# 498          499         0       1
# 177          178         0       1
# 505          506         0       1
# 748          749         0       1
# ..           ...       ...     ...
# 579          580         1       3
# 838          839         1       3
# 400          401         1       3
# 414          415         1       3
# 338          339         1       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 297                     Allison, Miss. Helen Loraine    1   2.0      1      2
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1  25.0      1      2
# 177                       Isham, Miss. Ann Elizabeth    1  50.0      0      0
# 505       Penasco y Castellana, Mr. Victor de Satode    0  18.0      1      0
# 748                        Marvin, Mr. Daniel Warner    0  19.0      1      0
# ...

# %%
#將embarked的C改0，Q改1，S改2
train.loc[train['Embarked'] =='C','Embarked']=0
train.loc[train['Embarked'] =='Q','Embarked']=1
train.loc[train['Embarked'] =='S','Embarked']=2
train
# Out:
#      PassengerId  Survived  Pclass  \
# 297          298         0       1
# 498          499         0       1
# 177          178         0       1
# 505          506         0       1
# 748          749         0       1
# ..           ...       ...     ...
# 579          580         1       3
# 838          839         1       3
# 400          401         1       3
# 414          415         1       3
# 338          339         1       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 297                     Allison, Miss. Helen Loraine    1   2.0      1      2
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1  25.0      1      2
# 177                       Isham, Miss. Ann Elizabeth    1  50.0      0      0
# 505       Penasco y Castellana, Mr. Victor de Satode    0  18.0      1      0
# 748                        Marvin, Mr. Daniel Warner    0  19.0      1      0
# ...

# %%
#查看有哪些不同的值，並計算每個值有多少個重複值
print('Survived:\n',pd.value_counts(train['Survived'].values.flatten()))
print('Pclass:\n',pd.value_counts(train['Pclass'].values.flatten()))
print('Sex:\n',pd.value_counts(train['Sex'].values.flatten()))
#survived 0:no,1:yes
#Sex 0:male,1:female
# Out:
# Survived:
#  0    549
# 1    342
# dtype: int64
# Pclass:
#  3    491
# 1    216
# 2    184
# dtype: int64
# Sex:
#  0    577
# 1    314
# dtype: int64

# %%
test = pd.read_csv(r'C:/Users/Cindy/Desktop/test.csv')
test['Survived']=''
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
test.loc[test['Sex'] =='male','Sex']=0
test.loc[test['Sex'] =='female','Sex']=1
test
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
# ...

# %%
#缺失值以中位數代替
test['Age'] = test['Age'].fillna(test['Age'].median())
test
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
# ...

# %%
#分別按'Survived','Pclass','Sex','Age'大小排列
test = test.sort_values(by=['Survived','Pclass','Sex','Age','SibSp','Parch'])
test
# Out:
#      PassengerId  Pclass                                             Name  \
# 196         1088       1                  Spedden, Master. Robert Douglas
# 64           956       1                      Ryerson, Master. John Borie
# 403         1295       1                           Carrau, Mr. Jose Pedro
# 23           915       1                  Williams, Mr. Richard Norris II
# 390         1282       1                       Payne, Mr. Vivian Ponsonby
# ..           ...     ...                                              ...
# 347         1239       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 214         1106       3           Andersson, Miss. Ida Augusta Margareta
# 19           911       3            Assaf Khalil, Mrs. Mariana (Miriam")"
# 309         1201       3       Hansen, Mrs. Claus Peter (Jennie L Howard)
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
#
#      Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked  \
# ...

# %%
data = pd.concat([train,test])
data
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       Age    Cabin Embarked      Fare  \
# 297   2.0  C22 C26        2  151.5500
# 498  25.0  C22 C26        2  151.5500
# 177  50.0      C49        0   28.7125
# 505  18.0      C65        0  108.9000
# 748  19.0      D30        2   53.1000
# ..    ...      ...      ...       ...
# 347  38.0      NaN        C    7.2292
# 214  38.0      NaN        S    7.7750
# 19   45.0      NaN        C    7.2250
# 309  45.0      NaN        S   14.1083
# 1    47.0      NaN        S    7.0000
#
#                                                 Name  Parch  PassengerId  \
# ...

# %%
data.loc[data['Embarked'] =='C','Embarked']=0
data.loc[data['Embarked'] =='Q','Embarked']=1
data.loc[data['Embarked'] =='S','Embarked']=2
data
# Out:
#       Age    Cabin Embarked      Fare  \
# 297   2.0  C22 C26        2  151.5500
# 498  25.0  C22 C26        2  151.5500
# 177  50.0      C49        0   28.7125
# 505  18.0      C65        0  108.9000
# 748  19.0      D30        2   53.1000
# ..    ...      ...      ...       ...
# 347  38.0      NaN        0    7.2292
# 214  38.0      NaN        2    7.7750
# 19   45.0      NaN        0    7.2250
# 309  45.0      NaN        2   14.1083
# 1    47.0      NaN        2    7.0000
#
#                                                 Name  Parch  PassengerId  \
# 297                     Allison, Miss. Helen Loraine      2          298
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      2          499
# 177                       Isham, Miss. Ann Elizabeth      0          178
# 505       Penasco y Castellana, Mr. Victor de Satode      0          506
# 748                        Marvin, Mr. Daniel Warner      0          749
# ...

# %%
data.shape
# Out:
# (1309, 12)

# %%
data[(data['Survived']!=0) & (data['Sex']==1)]
# Out:
#       Age    Cabin Embarked      Fare  \
# 435  14.0  B96 B98        2  120.0000
# 689  15.0       B5        2  211.3375
# 504  16.0      B79        2   86.5000
# 329  16.0      B18        0   57.9792
# 853  16.0      D28        2   39.4000
# ..    ...      ...      ...       ...
# 347  38.0      NaN        0    7.2292
# 214  38.0      NaN        2    7.7750
# 19   45.0      NaN        0    7.2250
# 309  45.0      NaN        2   14.1083
# 1    47.0      NaN        2    7.0000
#
#                                                 Name  Parch  PassengerId  \
# 435                        Carter, Miss. Lucile Polk      2          436
# 689                Madill, Miss. Georgette Alexandra      1          690
# 504                            Maioni, Miss. Roberta      0          505
# 329                     Hippach, Miss. Jean Gertrude      1          330
# 853                        Lines, Miss. Mary Conover      1          854
# ...

# %%
data[(data['Survived']!=0) & (data['Sex']==0)]
# Out:
#        Age    Cabin Embarked      Fare                                 Name  \
# 305   0.92  C22 C26        2  151.5500       Allison, Master. Hudson Trevor
# 445   4.00      A34        2   81.8583            Dodge, Master. Washington
# 802  11.00  B96 B98        2  120.0000  Carter, Master. William Thornton II
# 550  17.00      C70        0  110.8833          Thayer, Mr. John Borland Jr
# 97   23.00  D10 D12        0   63.3583      Greenfield, Mr. William Bertram
# ..     ...      ...      ...       ...                                  ...
# 228  40.50      NaN        2   15.1000            Everett, Mr. Thomas James
# 42   41.00      NaN        2    7.8500                Goldsmith, Mr. Nathan
# 134  43.00      NaN        2    7.8958               Dintcheff, Mr. Valtcho
# 25   50.00      NaN        2   14.5000              Robins, Mr. Alexander A
# 152  60.50      NaN        2       NaN                   Storey, Mr. Thomas
#
# ...

# %%
test = test.fillna(value=True)
train = train.fillna(value=True)
data = data.fillna(value=True)

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split 
import numpy as np
#建立一個模型model為線性迴歸模型
model = LinearRegression()

# %%
#X = train.drop(labels=['Name','Cabin','Ticket'],axis='columns')
#y = test.drop(labels=['Name','Cabin','Ticket'],axis='columns')
X_train = train.drop(labels=['Name','Cabin','Ticket','Survived'],axis='columns') #刪除這些欄位
y_train = train['Survived']
X_test = test.drop(labels=['Name','Cabin','Ticket','Survived'],axis='columns')
y_test = test['Survived']

# %%
#放進模型內訓練

model.fit(X.astype(float),y.astype(float))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-406-bc875f0fe8e4> in <module>
#       1 #放進模型內訓練
#       2
# ----> 3 model.fit(X.astype(float),y.astype(float))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
#predict 使用線性模型進行預測
y_pred = model.predict(int(float(X_test)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-368-0175abae2673> in <module>
#       1 #predict 使用線性模型進行預測
# ----> 2 y_pred = model.predict(int(float(X_test)))
#
# TypeError: float() argument must be a string or a number, not 'DataFrame'

# %%
y_test = np.array(list(y_test))
y_pred = np.array(y_pred)

# %%
#顯示實際值和預測值
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
