# %% [markdown]
# ### 導入train,test資料
# ### 合併資料

# %%
import pandas as pd
train = pd.read_csv(r'C:/Users/Cindy/Desktop/house-price/train.csv')
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
test = pd.read_csv(r'C:/Users/Cindy/Desktop/house-price/test.csv')
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
data = pd.concat([train,test])
data
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          856       854          0   NaN             3     1Fam       TA
# 1         1262         0          0   NaN             3     1Fam       TA
# 2          920       866          0   NaN             3     1Fam       TA
# 3          961       756          0   NaN             3     1Fam       Gd
# 4         1145      1053          0   NaN             4     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 1454       546       546          0   NaN             3    Twnhs       TA
# 1455       546       546          0   NaN             3   TwnhsE       TA
# 1456      1224         0          0   NaN             4     1Fam       TA
# 1457       970         0          0   NaN             3     1Fam       TA
# 1458       996      1004          0   NaN             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... SaleType ScreenPorch  Street  \
# 0              No       706.0         0.0  ...       WD           0    Pave
# 1              Gd       978.0         0.0  ...       WD           0    Pave
# 2              Mn       486.0         0.0  ...       WD           0    Pave
# 3              No       216.0         0.0  ...       WD           0    Pave
# 4              Av       655.0         0.0  ...       WD           0    Pave
# ...           ...         ...         ...  ...      ...         ...     ...
# 1454           No         0.0         0.0  ...       WD           0    Pave
# 1455           No       252.0         0.0  ...       WD           0    Pave
# 1456           No      1224.0         0.0  ...       WD           0    Pave
# 1457           Av       337.0         0.0  ...       WD           0    Pave
# 1458           Av       758.0         0.0  ...       WD           0    Pave
#
#       TotRmsAbvGrd TotalBsmtSF  Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0                8       856.0     AllPub          0      2003         2003
# 1                6      1262.0     AllPub        298      1976         1976
# 2                6       920.0     AllPub          0      2001         2002
# 3                7       756.0     AllPub          0      1915         1970
# 4                9      1145.0     AllPub        192      2000         2000
# ...            ...         ...        ...        ...       ...          ...
# 1454             5       546.0     AllPub          0      1970         1970
# 1455             6       546.0     AllPub          0      1970         1970
# 1456             7      1224.0     AllPub        474      1960         1996
# 1457             6       912.0     AllPub         80      1992         1992
# 1458             9       996.0     AllPub        190      1993         1994
#
#      YrSold
# 0      2008
# 1      2007
# 2      2008
# 3      2006
# 4      2008
# ...     ...
# 1454   2006
# 1455   2006
# 1456   2006
# 1457   2006
# 1458   2006
#
# [2919 rows x 81 columns]

# %% [markdown]
# ### 分出data之dtype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
# 1stFlrSF         2919 non-null int64
# 2ndFlrSF         2919 non-null int64
# 3SsnPorch        2919 non-null int64
# Alley            198 non-null object
# BedroomAbvGr     2919 non-null int64
# BldgType         2919 non-null object
# BsmtCond         2837 non-null object
# BsmtExposure     2837 non-null object
# BsmtFinSF1       2918 non-null float64
# BsmtFinSF2       2918 non-null float64
# BsmtFinType1     2840 non-null object
# BsmtFinType2     2839 non-null object
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtQual         2838 non-null object
# BsmtUnfSF        2918 non-null float64
# CentralAir       2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# Electrical       2918 non-null object
# EnclosedPorch    2919 non-null int64
# ExterCond        2919 non-null object
# ExterQual        2919 non-null object
# Exterior1st      2918 non-null object
# Exterior2nd      2918 non-null object
# Fence            571 non-null object
# FireplaceQu      1499 non-null object
# Fireplaces       2919 non-null int64
# Foundation       2919 non-null object
# FullBath         2919 non-null int64
# Functional       2917 non-null object
# GarageArea       2918 non-null float64
# GarageCars       2918 non-null float64
# GarageCond       2760 non-null object
# GarageFinish     2760 non-null object
# GarageQual       2760 non-null object
# GarageType       2762 non-null object
# GarageYrBlt      2760 non-null float64
# GrLivArea        2919 non-null int64
# HalfBath         2919 non-null int64
# Heating          2919 non-null object
# HeatingQC        2919 non-null object
# HouseStyle       2919 non-null object
# Id               2919 non-null int64
# KitchenAbvGr     2919 non-null int64
# KitchenQual      2918 non-null object
# LandContour      2919 non-null object
# LandSlope        2919 non-null object
# LotArea          2919 non-null int64
# LotConfig        2919 non-null object
# LotFrontage      2433 non-null float64
# LotShape         2919 non-null object
# LowQualFinSF     2919 non-null int64
# MSSubClass       2919 non-null int64
# MSZoning         2915 non-null object
# MasVnrArea       2896 non-null float64
# MasVnrType       2895 non-null object
# MiscFeature      105 non-null object
# MiscVal          2919 non-null int64
# MoSold           2919 non-null int64
# Neighborhood     2919 non-null object
# OpenPorchSF      2919 non-null int64
# OverallCond      2919 non-null int64
# OverallQual      2919 non-null int64
# PavedDrive       2919 non-null object
# PoolArea         2919 non-null int64
# PoolQC           10 non-null object
# RoofMatl         2919 non-null object
# RoofStyle        2919 non-null object
# SaleCondition    2919 non-null object
# SalePrice        1460 non-null float64
# SaleType         2918 non-null object
# ScreenPorch      2919 non-null int64
# Street           2919 non-null object
# TotRmsAbvGrd     2919 non-null int64
# TotalBsmtSF      2918 non-null float64
# Utilities        2917 non-null object
# WoodDeckSF       2919 non-null int64
# YearBuilt        2919 non-null int64
# YearRemodAdd     2919 non-null int64
# YrSold           2919 non-null int64
# dtypes: float64(12), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ### 處理object

# %%
#以n填補空值
#obj=obj.fillna('n')
#for i in range (0,43):
 #   obj.iloc[:,i] = obj.iloc[:,i].str[0:1]
#obj
# Out:
#      Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0        n        1        T            N            G            U        G
# 1        n        1        T            G            A            U        G
# 2        n        1        T            M            G            U        G
# 3        n        1        G            N            A            U        T
# 4        n        1        T            A            G            U        G
# ...    ...      ...      ...          ...          ...          ...      ...
# 1454     n        T        T            N            U            U        T
# 1455     n        T        T            N            R            U        T
# 1456     n        1        T            N            A            U        T
# 1457     n        1        T            A            G            U        G
# 1458     n        1        T            A            L            U        G
#
#      CentralAir Condition1 Condition2  ... MiscFeature Neighborhood  \
# 0             Y          N          N  ...           n            C
# 1             Y          F          N  ...           n            V
# 2             Y          N          N  ...           n            C
# 3             Y          N          N  ...           n            C
# 4             Y          N          N  ...           n            N
# ...         ...        ...        ...  ...         ...          ...
# 1454          Y          N          N  ...           n            M
# 1455          Y          N          N  ...           n            M
# 1456          Y          N          N  ...           n            M
# 1457          Y          N          N  ...           S            M
# 1458          Y          N          N  ...           n            M
#
#      PavedDrive PoolQC RoofMatl RoofStyle SaleCondition SaleType Street  \
# 0             Y      n        C         G             N        W      P
# 1             Y      n        C         G             N        W      P
# 2             Y      n        C         G             N        W      P
# 3             Y      n        C         G             A        W      P
# 4             Y      n        C         G             N        W      P
# ...         ...    ...      ...       ...           ...      ...    ...
# 1454          Y      n        C         G             N        W      P
# 1455          Y      n        C         G             A        W      P
# 1456          Y      n        C         G             A        W      P
# 1457          Y      n        C         G             N        W      P
# 1458          Y      n        C         G             N        W      P
#
#      Utilities
# 0            A
# 1            A
# 2            A
# 3            A
# 4            A
# ...        ...
# 1454         A
# 1455         A
# 1456         A
# 1457         A
# 1458         A
#
# [2919 rows x 43 columns]

# %%
#a=[]
#for i in range (0,43):
 #   print(obj.columns[i],':\n',pd.value_counts(obj.iloc[:,i].values.flatten()))
   # a[]

# %%
#obj.columns[0],pd.value_counts(obj.iloc[:,0].values.flatten())

# %%
#obj=obj.loc[obj['Alley'] =='n','Alley']=2
#obj

# %%
#obj.loc[:,[0]] = [ord(obj)]

# %%
#ord('n')

# %%
#是否存在空值
#data.isnull().any()

# %% [markdown]
# ### Alley: 轉換第一個字母為數字

# %%
##data['Alley'] = data['Alley'].astype(str).str[0:1]

# %%
#print('Alley:\n',pd.value_counts(data['Alley'].values.flatten()))

# %%
#data.loc[data['Alley'] =='n','Alley']=0
#data.loc[data['Alley'] =='G','Alley']=1
#data.loc[data['Alley'] =='P','Alley']=2
#data

# %% [markdown]
# ### 處理int, float

# %%
num = data.select_dtypes(exclude=['object'])
num
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# 0              1.0           0.0      150.0              0  ...            7
# 1              0.0           1.0      284.0              0  ...            6
# 2              1.0           0.0      434.0              0  ...            7
# 3              1.0           0.0      540.0            272  ...            7
# 4              1.0           0.0      490.0              0  ...            8
# ...            ...           ...        ...            ...  ...          ...
# 1454           0.0           0.0      546.0              0  ...            4
# 1455           0.0           0.0      294.0              0  ...            4
# 1456           1.0           0.0        0.0              0  ...            5
# 1457           0.0           1.0      575.0              0  ...            5
# 1458           0.0           0.0      238.0              0  ...            7
#
#       PoolArea  SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0            0   208500.0            0             8        856.0           0
# 1            0   181500.0            0             6       1262.0         298
# 2            0   223500.0            0             6        920.0           0
# 3            0   140000.0            0             7        756.0           0
# 4            0   250000.0            0             9       1145.0         192
# ...        ...        ...          ...           ...          ...         ...
# 1454         0        NaN            0             5        546.0           0
# 1455         0        NaN            0             6        546.0           0
# 1456         0        NaN            0             7       1224.0         474
# 1457         0        NaN            0             6        912.0          80
# 1458         0        NaN            0             9        996.0         190
#
#       YearBuilt  YearRemodAdd  YrSold
# 0          2003          2003    2008
# 1          1976          1976    2007
# 2          2001          2002    2008
# 3          1915          1970    2006
# 4          2000          2000    2008
# ...         ...           ...     ...
# 1454       1970          1970    2006
# 1455       1970          1970    2006
# 1456       1960          1996    2006
# 1457       1992          1992    2006
# 1458       1993          1994    2006
#
# [2919 rows x 38 columns]

# %%
num.shape
# Out:
# (2919, 38)

# %% [markdown]
# ### df1:前10筆資料

# %%
df1 = num.iloc[:,0:10]
df1
#1stFlrSF: First Floor square feet
#2ndFlrSF: Second floor square feet
#3SsnPorch: Three season porch area in square feet
#BsmtFinSF1: Type 1 finished square feet
#BsmtFinSF2: Type 2 finished square feet
#BsmtFullBath: Basement full bathrooms
#BsmtHalfBath: Basement half bathrooms
#BsmtUnfSF: Unfinished square feet of basement area
#EnclosedPorch: Enclosed porch area in square feet
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch
# 0              1.0           0.0      150.0              0
# 1              0.0           1.0      284.0              0
# 2              1.0           0.0      434.0              0
# 3              1.0           0.0      540.0            272
# 4              1.0           0.0      490.0              0
# ...            ...           ...        ...            ...
# 1454           0.0           0.0      546.0              0
# 1455           0.0           0.0      294.0              0
# 1456           1.0           0.0        0.0              0
# 1457           0.0           1.0      575.0              0
# 1458           0.0           0.0      238.0              0
#
# [2919 rows x 10 columns]

# %%
df1.describe()
# Out:
#           1stFlrSF     2ndFlrSF    3SsnPorch  BedroomAbvGr   BsmtFinSF1  \
# count  2919.000000  2919.000000  2919.000000   2919.000000  2918.000000
# mean   1159.581706   336.483727     2.602261      2.860226   441.423235
# std     392.362079   428.701456    25.188169      0.822693   455.610826
# min     334.000000     0.000000     0.000000      0.000000     0.000000
# 25%     876.000000     0.000000     0.000000      2.000000     0.000000
# 50%    1082.000000     0.000000     0.000000      3.000000   368.500000
# 75%    1387.500000   704.000000     0.000000      3.000000   733.000000
# max    5095.000000  2065.000000   508.000000      8.000000  5644.000000
#
#         BsmtFinSF2  BsmtFullBath  BsmtHalfBath    BsmtUnfSF  EnclosedPorch
# count  2918.000000   2917.000000   2917.000000  2918.000000    2919.000000
# mean     49.582248      0.429894      0.061364   560.772104      23.098321
# std     169.205611      0.524736      0.245687   439.543659      64.244246
# min       0.000000      0.000000      0.000000     0.000000       0.000000
# 25%       0.000000      0.000000      0.000000   220.000000       0.000000
# 50%       0.000000      0.000000      0.000000   467.000000       0.000000
# 75%       0.000000      1.000000      0.000000   805.500000       0.000000
# max    1526.000000      3.000000      2.000000  2336.000000    1012.000000

# %%
df1 = df1.drop(labels=['3SsnPorch','BsmtFinSF2','BsmtHalfBath','EnclosedPorch'],axis='columns')
df1
# Out:
#       1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtFinSF1  BsmtFullBath  BsmtUnfSF
# 0          856       854             3       706.0           1.0      150.0
# 1         1262         0             3       978.0           0.0      284.0
# 2          920       866             3       486.0           1.0      434.0
# 3          961       756             3       216.0           1.0      540.0
# 4         1145      1053             4       655.0           1.0      490.0
# ...        ...       ...           ...         ...           ...        ...
# 1454       546       546             3         0.0           0.0      546.0
# 1455       546       546             3       252.0           0.0      294.0
# 1456      1224         0             4      1224.0           1.0        0.0
# 1457       970         0             3       337.0           0.0      575.0
# 1458       996      1004             3       758.0           0.0      238.0
#
# [2919 rows x 6 columns]

# %%
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
df1.plot()

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002772AFBD788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772AF556C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772B039808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772B06F908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772B0A9A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772B0E2B08>]],
#       dtype=object)

# %% [markdown]
# ### 去除離峰值(常態分佈)

# %%
std = df1.std()
mean = df1.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (1stFlrSF        -17.504530
#  2ndFlrSF       -949.620639
#  BedroomAbvGr      0.392147
#  BsmtFinSF1     -925.409243
#  BsmtFullBath     -1.144313
#  BsmtUnfSF      -757.858874
#  dtype: float64, 1stFlrSF        2336.667942
#  2ndFlrSF        1622.588094
#  BedroomAbvGr       5.328305
#  BsmtFinSF1      1808.255713
#  BsmtFullBath       2.004101
#  BsmtUnfSF       1879.403082
#  dtype: float64)

# %%
cond=((df1>ma) | (df1<mi))
cond
# Out:
#       1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtFinSF1  BsmtFullBath  BsmtUnfSF
# 0        False     False         False       False         False      False
# 1        False     False         False       False         False      False
# 2        False     False         False       False         False      False
# 3        False     False         False       False         False      False
# 4        False     False         False       False         False      False
# ...        ...       ...           ...         ...           ...        ...
# 1454     False     False         False       False         False      False
# 1455     False     False         False       False         False      False
# 1456     False     False         False       False         False      False
# 1457     False     False         False       False         False      False
# 1458     False     False         False       False         False      False
#
# [2919 rows x 6 columns]

# %%
#各行離峰值數量
cond.sum()
# Out:
# 1stFlrSF        29
# 2ndFlrSF        10
# BedroomAbvGr    30
# BsmtFinSF1      17
# BsmtFullBath     2
# BsmtUnfSF       16
# dtype: int64

# %%
#any()用法: 是否有元素為true
cond=cond.any(axis=1)

# %%
#離峰值
df1[cond]
# Out:
#       1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtFinSF1  BsmtFullBath  BsmtUnfSF
# 53        1842         0             0      1810.0           2.0       32.0
# 70        2223         0             3      1880.0           1.0      343.0
# 137       1959         0             5         0.0           0.0     1907.0
# 144       1728         0             6      1332.0           1.0      396.0
# 178       2234         0             1      1904.0           1.0      312.0
# ...        ...       ...           ...         ...           ...        ...
# 1229      2036       604             3      1836.0           1.0      200.0
# 1342      1921         0             4         0.0           0.0     1921.0
# 1352      1967         0             6         0.0           0.0     1967.0
# 1353      1949         0             6       483.0           0.0     1466.0
# 1362      1836      1836             5       425.0           0.0     1411.0
#
# [85 rows x 6 columns]

# %%
#index() 函数用于从列表中找出某个值第一个匹配项的索引位置
#drop 刪除資料
df1_10=df1.drop(labels=df1[cond].index)
df1_10
# Out:
#       1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtFinSF1  BsmtFullBath  BsmtUnfSF
# 0          856       854             3       706.0           1.0      150.0
# 1         1262         0             3       978.0           0.0      284.0
# 2          920       866             3       486.0           1.0      434.0
# 3          961       756             3       216.0           1.0      540.0
# 4         1145      1053             4       655.0           1.0      490.0
# ...        ...       ...           ...         ...           ...        ...
# 1454       546       546             3         0.0           0.0      546.0
# 1455       546       546             3       252.0           0.0      294.0
# 1456      1224         0             4      1224.0           1.0        0.0
# 1457       970         0             3       337.0           0.0      575.0
# 1458       996      1004             3       758.0           0.0      238.0
#
# [2755 rows x 6 columns]

# %%
#去除離峰值#未去除離峰值
df1_10.describe(),df1.describe()
# Out:
# (          1stFlrSF     2ndFlrSF  BedroomAbvGr   BsmtFinSF1  BsmtFullBath  \
#  count  2755.000000  2755.000000   2755.000000  2754.000000   2754.000000
#  mean   1133.696552   331.705626      2.839201   429.409223      0.418301
#  std     345.846871   417.049962      0.752572   421.612495      0.508596
#  min     334.000000     0.000000      1.000000     0.000000      0.000000
#  25%     871.500000     0.000000      2.000000     0.000000      0.000000
#  50%    1072.000000     0.000000      3.000000   368.000000      0.000000
#  75%    1363.000000   702.000000      3.000000   724.750000      1.000000
#  max    2290.000000  1611.000000      5.000000  1758.000000      2.000000
#
#           BsmtUnfSF
#  count  2754.000000
#  mean    547.770153
#  std     421.573345
#  min       0.000000
#  25%     218.000000
#  50%     461.000000
#  75%     788.750000
#  max    1869.000000  ,
#            1stFlrSF     2ndFlrSF  BedroomAbvGr   BsmtFinSF1  BsmtFullBath  \
#  count  2919.000000  2919.000000   2919.000000  2918.000000   2917.000000
#  mean   1159.581706   336.483727      2.860226   441.423235      0.429894
#  std     392.362079   428.701456      0.822693   455.610826      0.524736
#  min     334.000000     0.000000      0.000000     0.000000      0.000000
#  25%     876.000000     0.000000      2.000000     0.000000      0.000000
#  50%    1082.000000     0.000000      3.000000   368.500000      0.000000
#  75%    1387.500000   704.000000      3.000000   733.000000      1.000000
#  max    5095.000000  2065.000000      8.000000  5644.000000      3.000000
#
#           BsmtUnfSF
#  count  2918.000000
#  mean    560.772104
#  std     439.543659
#  min       0.000000
#  25%     220.000000
#  50%     467.000000
#  75%     805.500000
#  max    2336.000000  )

# %%
df1_10.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002772B277D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772B283308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772B2B50C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772B2E91C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772B31E308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772B351D48>]],
#       dtype=object)

# %% [markdown]
# ### df2 11-20筆資料

# %%
df2=num.iloc[:,10:20]
df2
#Fireplaces: Number of fireplaces
#FullBath: Full bathrooms above grade
#GarageArea: Size of garage in square feet
#GarageCars: Size of garage in car capacity
#GarageYrBlt: Year garage was built
#GrLivArea: Above grade (ground) living area square feet
#HalfBath: Half baths above grade
#LotArea: Lot size in square feet
# Out:
#       Fireplaces  FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  \
# 0              0         2       548.0         2.0       2003.0       1710
# 1              1         2       460.0         2.0       1976.0       1262
# 2              1         2       608.0         2.0       2001.0       1786
# 3              1         1       642.0         3.0       1998.0       1717
# 4              1         2       836.0         3.0       2000.0       2198
# ...          ...       ...         ...         ...          ...        ...
# 1454           0         1         0.0         0.0          NaN       1092
# 1455           0         1       286.0         1.0       1970.0       1092
# 1456           1         1       576.0         2.0       1960.0       1224
# 1457           0         1         0.0         0.0          NaN        970
# 1458           1         2       650.0         3.0       1993.0       2000
#
#       HalfBath    Id  KitchenAbvGr  LotArea
# 0            1     1             1     8450
# 1            0     2             1     9600
# 2            1     3             1    11250
# 3            0     4             1     9550
# 4            1     5             1    14260
# ...        ...   ...           ...      ...
# 1454         1  2915             1     1936
# 1455         1  2916             1     1894
# 1456         0  2917             1    20000
# 1457         0  2918             1    10441
# 1458         1  2919             1     9627
#
# [2919 rows x 10 columns]

# %%
df2.describe()
# Out:
#         Fireplaces     FullBath   GarageArea   GarageCars  GarageYrBlt  \
# count  2919.000000  2919.000000  2918.000000  2918.000000  2760.000000
# mean      0.597122     1.568003   472.874572     1.766621  1978.113406
# std       0.646129     0.552969   215.394815     0.761624    25.574285
# min       0.000000     0.000000     0.000000     0.000000  1895.000000
# 25%       0.000000     1.000000   320.000000     1.000000  1960.000000
# 50%       1.000000     2.000000   480.000000     2.000000  1979.000000
# 75%       1.000000     2.000000   576.000000     2.000000  2002.000000
# max       4.000000     4.000000  1488.000000     5.000000  2207.000000
#
#          GrLivArea     HalfBath           Id  KitchenAbvGr        LotArea
# count  2919.000000  2919.000000  2919.000000   2919.000000    2919.000000
# mean   1500.759849     0.380267  1460.000000      1.044536   10168.114080
# std     506.051045     0.502872   842.787043      0.214462    7886.996359
# min     334.000000     0.000000     1.000000      0.000000    1300.000000
# 25%    1126.000000     0.000000   730.500000      1.000000    7478.000000
# 50%    1444.000000     0.000000  1460.000000      1.000000    9453.000000
# 75%    1743.500000     1.000000  2189.500000      1.000000   11570.000000
# max    5642.000000     2.000000  2919.000000      3.000000  215245.000000

# %% [markdown]
# ### 去除離峰值

# %%
std = df2.std()
mean = df2.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (Fireplaces         -1.341266
#  FullBath           -0.090905
#  GarageArea       -173.309873
#  GarageCars         -0.518252
#  GarageYrBlt      1901.390552
#  GrLivArea         -17.393286
#  HalfBath           -1.128348
#  Id              -1068.361129
#  KitchenAbvGr        0.401150
#  LotArea        -13492.874997
#  dtype: float64, Fireplaces          2.535510
#  FullBath            3.226911
#  GarageArea       1119.059017
#  GarageCars          4.051494
#  GarageYrBlt      2054.836260
#  GrLivArea        3018.912985
#  HalfBath            1.888882
#  Id               3988.361129
#  KitchenAbvGr        1.687922
#  LotArea         33829.103157
#  dtype: float64)

# %%
cond2=((df2>ma) | (df2<mi))
cond2
# Out:
#       Fireplaces  FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  \
# 0          False     False       False       False        False      False
# 1          False     False       False       False        False      False
# 2          False     False       False       False        False      False
# 3          False     False       False       False        False      False
# 4          False     False       False       False        False      False
# ...          ...       ...         ...         ...          ...        ...
# 1454       False     False       False       False        False      False
# 1455       False     False       False       False        False      False
# 1456       False     False       False       False        False      False
# 1457       False     False       False       False        False      False
# 1458       False     False       False       False        False      False
#
#       HalfBath     Id  KitchenAbvGr  LotArea
# 0        False  False         False    False
# 1        False  False         False    False
# 2        False  False         False    False
# 3        False  False         False    False
# 4        False  False         False    False
# ...        ...    ...           ...      ...
# 1454     False  False         False    False
# 1455     False  False         False    False
# 1456     False  False         False    False
# 1457     False  False         False    False
# 1458     False  False         False    False
#
# [2919 rows x 10 columns]

# %%
#各行離峰值數量
cond2.sum()
# Out:
# Fireplaces       12
# FullBath          4
# GarageArea       17
# GarageCars        1
# GarageYrBlt       9
# GrLivArea        25
# HalfBath         25
# Id                0
# KitchenAbvGr    134
# LotArea          29
# dtype: int64

# %%
#any()用法: 是否有元素為true
cond2=cond2.any(axis=1)

# %%
#離峰值
df2[cond2]
# Out:
#       Fireplaces  FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  \
# 8              2         2       468.0         2.0       1931.0       1774
# 9              2         1       205.0         1.0       1939.0       1077
# 17             0         2       516.0         2.0       1967.0       1296
# 39             0         2         0.0         0.0          NaN       1152
# 48             0         2         0.0         0.0          NaN       1452
# ...          ...       ...         ...         ...          ...        ...
# 1432           0         2         0.0         0.0          NaN       1396
# 1437           0         2       616.0         2.0       1978.0       1664
# 1440           2         1       518.0         2.0       1958.0       1650
# 1445           0         2       784.0         4.0       1997.0       1368
# 1448           0         2       928.0         3.0       1970.0       1652
#
#       HalfBath    Id  KitchenAbvGr  LotArea
# 8            0     9             2     6120
# 9            0    10             2     7420
# 17           0    18             2    10791
# 39           0    40             2     6040
# 48           0    49             3     4456
# ...        ...   ...           ...      ...
# 1432         0  2893             2     9000
# 1437         0  2898             2     8385
# 1440         0  2901             1    50102
# 1445         0  2906             2     7020
# 1448         0  2909             2    11836
#
# [222 rows x 10 columns]

# %%
#index() 函数用于从列表中找出某个值第一个匹配项的索引位置
#drop 刪除資料
df11_20=df2.drop(labels=df2[cond2].index)
df11_20
# Out:
#       Fireplaces  FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  \
# 0              0         2       548.0         2.0       2003.0       1710
# 1              1         2       460.0         2.0       1976.0       1262
# 2              1         2       608.0         2.0       2001.0       1786
# 3              1         1       642.0         3.0       1998.0       1717
# 4              1         2       836.0         3.0       2000.0       2198
# ...          ...       ...         ...         ...          ...        ...
# 1454           0         1         0.0         0.0          NaN       1092
# 1455           0         1       286.0         1.0       1970.0       1092
# 1456           1         1       576.0         2.0       1960.0       1224
# 1457           0         1         0.0         0.0          NaN        970
# 1458           1         2       650.0         3.0       1993.0       2000
#
#       HalfBath    Id  KitchenAbvGr  LotArea
# 0            1     1             1     8450
# 1            0     2             1     9600
# 2            1     3             1    11250
# 3            0     4             1     9550
# 4            1     5             1    14260
# ...        ...   ...           ...      ...
# 1454         1  2915             1     1936
# 1455         1  2916             1     1894
# 1456         0  2917             1    20000
# 1457         0  2918             1    10441
# 1458         1  2919             1     9627
#
# [2495 rows x 10 columns]

# %%
#去除離峰值，未去除離峰值
df11_20.describe(),df2.describe()
# Out:
# (        Fireplaces     FullBath   GarageArea   GarageCars  GarageYrBlt  \
#  count  2495.000000  2495.000000  2494.000000  2494.000000  2379.000000
#  mean      0.582766     1.533868   467.612670     1.754611  1978.724674
#  std       0.609553     0.532387   201.389959     0.730907    24.911725
#  min       0.000000     0.000000     0.000000     0.000000  1906.000000
#  25%       0.000000     1.000000   317.250000     1.000000  1961.000000
#  50%       1.000000     2.000000   474.500000     2.000000  1980.000000
#  75%       1.000000     2.000000   576.000000     2.000000  2002.000000
#  max       2.000000     3.000000  1092.000000     4.000000  2010.000000
#
#           GrLivArea     HalfBath           Id  KitchenAbvGr       LotArea
#  count  2495.000000  2495.000000  2495.000000        2495.0   2495.000000
#  mean   1459.131864     0.375150  1456.521844           1.0   9548.457715
#  std     458.124820     0.484259   842.764573           0.0   3898.289054
#  min     334.000000     0.000000     1.000000           1.0   1300.000000
#  25%    1103.000000     0.000000   733.500000           1.0   7379.500000
#  50%    1416.000000     0.000000  1460.000000           1.0   9364.000000
#  75%    1710.000000     1.000000  2192.500000           1.0  11416.500000
#  max    3005.000000     1.000000  2919.000000           1.0  31770.000000  ,
#          Fireplaces     FullBath   GarageArea   GarageCars  GarageYrBlt  \
#  count  2919.000000  2919.000000  2918.000000  2918.000000  2760.000000
#  mean      0.597122     1.568003   472.874572     1.766621  1978.113406
#  std       0.646129     0.552969   215.394815     0.761624    25.574285
#  min       0.000000     0.000000     0.000000     0.000000  1895.000000
#  25%       0.000000     1.000000   320.000000     1.000000  1960.000000
#  50%       1.000000     2.000000   480.000000     2.000000  1979.000000
#  75%       1.000000     2.000000   576.000000     2.000000  2002.000000
#  max       4.000000     4.000000  1488.000000     5.000000  2207.000000
#
#           GrLivArea     HalfBath           Id  KitchenAbvGr        LotArea
#  count  2919.000000  2919.000000  2919.000000   2919.000000    2919.000000
#  mean   1500.759849     0.380267  1460.000000      1.044536   10168.114080
#  std     506.051045     0.502872   842.787043      0.214462    7886.996359
#  min     334.000000     0.000000     1.000000      0.000000    1300.000000
#  25%    1126.000000     0.000000   730.500000      1.000000    7478.000000
#  50%    1444.000000     0.000000  1460.000000      1.000000    9453.000000
#  75%    1743.500000     1.000000  2189.500000      1.000000   11570.000000
#  max    5642.000000     2.000000  2919.000000      3.000000  215245.000000  )

# %%
df11_20.hist(),df2.hist()
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002772DCF7408>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772ED38FC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772ED57708>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772ED90148>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772EDC5B48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772EDFE548>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772EE35E88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772EE6E8C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772EE79408>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772EEADFC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772EF1A588>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772EF516C8>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002772EF96788>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772ED47A48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F117F48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772F154088>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F18D188>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F1C4288>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772F1FD3C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F23DF08>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F2460C8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772F27B2C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F2E1788>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002772F318948>]],
#        dtype=object))

# %% [markdown]
# ### df3 21-30筆資料

# %%
df3 = num.iloc[:,20:30]
df3
#LotFrontage: Linear feet of street connected to property
#LowQualFinSF: Low quality finished square feet (all floors)
#MSSubClass: Identifies the type of dwelling involved in the sale.
#MiscVal: $Value of miscellaneous feature
#MoSold: Month Sold (MM)
#OpenPorchSF: Open porch area in square feet
#OverallCond: Rates the overall condition of the house
#OverallQual: Rates the overall material and finish of the house
#PoolArea: Pool area in square feet
# Out:
#       LotFrontage  LowQualFinSF  MSSubClass  MasVnrArea  MiscVal  MoSold  \
# 0            65.0             0          60       196.0        0       2
# 1            80.0             0          20         0.0        0       5
# 2            68.0             0          60       162.0        0       9
# 3            60.0             0          70         0.0        0       2
# 4            84.0             0          60       350.0        0      12
# ...           ...           ...         ...         ...      ...     ...
# 1454         21.0             0         160         0.0        0       6
# 1455         21.0             0         160         0.0        0       4
# 1456        160.0             0          20         0.0        0       9
# 1457         62.0             0          85         0.0      700       7
# 1458         74.0             0          60        94.0        0      11
#
#       OpenPorchSF  OverallCond  OverallQual  PoolArea
# 0              61            5            7         0
# 1               0            8            6         0
# 2              42            5            7         0
# 3              35            5            7         0
# 4              84            5            8         0
# ...           ...          ...          ...       ...
# 1454            0            7            4         0
# 1455           24            5            4         0
# 1456            0            7            5         0
# 1457           32            5            5         0
# 1458           48            5            7         0
#
# [2919 rows x 10 columns]

# %%
df3.loc[df3['MSSubClass'] ==20,'MSSubClass']=0
df3.loc[df3['MSSubClass'] ==30,'MSSubClass']=1
df3.loc[df3['MSSubClass'] ==40,'MSSubClass']=2
df3.loc[df3['MSSubClass'] ==45,'MSSubClass']=3
df3.loc[df3['MSSubClass'] ==50,'MSSubClass']=4
df3.loc[df3['MSSubClass'] ==60,'MSSubClass']=5
df3.loc[df3['MSSubClass'] ==70,'MSSubClass']=6
df3.loc[df3['MSSubClass'] ==75,'MSSubClass']=7
df3.loc[df3['MSSubClass'] ==80,'MSSubClass']=8
df3.loc[df3['MSSubClass'] ==85,'MSSubClass']=9
df3.loc[df3['MSSubClass'] ==90,'MSSubClass']=10
df3.loc[df3['MSSubClass'] ==120,'MSSubClass']=11
df3.loc[df3['MSSubClass'] ==150,'MSSubClass']=12
df3.loc[df3['MSSubClass'] ==160,'MSSubClass']=13
df3.loc[df3['MSSubClass'] ==180,'MSSubClass']=14
df3.loc[df3['MSSubClass'] ==190,'MSSubClass']=15

# %%
df3.describe()
# Out:
#        LotFrontage  LowQualFinSF   MSSubClass   MasVnrArea       MiscVal  \
# count  2433.000000   2919.000000  2919.000000  2896.000000   2919.000000
# mean     69.305795      4.694416     4.266530   102.201312     50.825968
# std      23.344905     46.396825     4.344907   179.334253    567.402211
# min      21.000000      0.000000     0.000000     0.000000      0.000000
# 25%      59.000000      0.000000     0.000000     0.000000      0.000000
# 50%      68.000000      0.000000     4.000000     0.000000      0.000000
# 75%      80.000000      0.000000     6.000000   164.000000      0.000000
# max     313.000000   1064.000000    15.000000  1600.000000  17000.000000
#
#             MoSold  OpenPorchSF  OverallCond  OverallQual     PoolArea
# count  2919.000000  2919.000000  2919.000000  2919.000000  2919.000000
# mean      6.213087    47.486811     5.564577     6.089072     2.251799
# std       2.714762    67.575493     1.113131     1.409947    35.663946
# min       1.000000     0.000000     1.000000     1.000000     0.000000
# 25%       4.000000     0.000000     5.000000     5.000000     0.000000
# 50%       6.000000    26.000000     5.000000     6.000000     0.000000
# 75%       8.000000    70.000000     6.000000     7.000000     0.000000
# max      12.000000   742.000000     9.000000    10.000000   800.000000

# %%
df3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002772FCA16C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772FEC1A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772FEEC988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772FF1DFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772FF57648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772FF88CC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002772FFBFA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772FFF87C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002772FFFE648>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277300365C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002773009BBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277300D2DC8>]],
#       dtype=object)

# %%
df3 = df3.drop(labels=['LowQualFinSF','MiscVal','PoolArea'],axis='columns')
df3
# Out:
#       LotFrontage  MSSubClass  MasVnrArea  MoSold  OpenPorchSF  OverallCond  \
# 0            65.0           5       196.0       2           61            5
# 1            80.0           0         0.0       5            0            8
# 2            68.0           5       162.0       9           42            5
# 3            60.0           6         0.0       2           35            5
# 4            84.0           5       350.0      12           84            5
# ...           ...         ...         ...     ...          ...          ...
# 1454         21.0          13         0.0       6            0            7
# 1455         21.0          13         0.0       4           24            5
# 1456        160.0           0         0.0       9            0            7
# 1457         62.0           9         0.0       7           32            5
# 1458         74.0           5        94.0      11           48            5
#
#       OverallQual
# 0               7
# 1               6
# 2               7
# 3               7
# 4               8
# ...           ...
# 1454            4
# 1455            4
# 1456            5
# 1457            5
# 1458            7
#
# [2919 rows x 7 columns]

# %% [markdown]
# ### 去除離峰值

# %%
std = df3.std()
mean = df3.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (LotFrontage     -0.728919
#  MSSubClass      -8.768192
#  MasVnrArea    -435.801447
#  MoSold          -1.931199
#  OpenPorchSF   -155.239670
#  OverallCond      2.225185
#  OverallQual      1.859230
#  dtype: float64, LotFrontage    139.340509
#  MSSubClass      17.301251
#  MasVnrArea     640.204071
#  MoSold          14.357372
#  OpenPorchSF    250.213291
#  OverallCond      8.903969
#  OverallQual     10.318913
#  dtype: float64)

# %%
cond3=((df3>ma) | (df3<mi))
cond3
# Out:
#       LotFrontage  MSSubClass  MasVnrArea  MoSold  OpenPorchSF  OverallCond  \
# 0           False       False       False   False        False        False
# 1           False       False       False   False        False        False
# 2           False       False       False   False        False        False
# 3           False       False       False   False        False        False
# 4           False       False       False   False        False        False
# ...           ...         ...         ...     ...          ...          ...
# 1454        False       False       False   False        False        False
# 1455        False       False       False   False        False        False
# 1456         True       False       False   False        False        False
# 1457        False       False       False   False        False        False
# 1458        False       False       False   False        False        False
#
#       OverallQual
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1454        False
# 1455        False
# 1456        False
# 1457        False
# 1458        False
#
# [2919 rows x 7 columns]

# %%
cond3.sum()
# Out:
# LotFrontage    22
# MSSubClass      0
# MasVnrArea     62
# MoSold          0
# OpenPorchSF    51
# OverallCond    58
# OverallQual     4
# dtype: int64

# %%
#any()用法: 是否有元素為true
cond3=cond3.any(axis=1)

# %%
#離峰值
df3[cond3]
# Out:
#       LotFrontage  MSSubClass  MasVnrArea  MoSold  OpenPorchSF  OverallCond  \
# 28           47.0           0         0.0      12          258            6
# 37           74.0           0       650.0      10            0            6
# 58           66.0           5      1031.0      10            0            5
# 70           95.0           0      1115.0       2            0            6
# 88          105.0           4         0.0      10            0            2
# ...           ...         ...         ...     ...          ...          ...
# 1363         78.0           8        96.0       5          253            5
# 1403         90.0           5         0.0       2          274            5
# 1439        140.0           8       257.0       5            0            6
# 1444        125.0           0         0.0       5            0            3
# 1456        160.0           0         0.0       9            0            7
#
#       OverallQual
# 28              5
# 37              5
# 58             10
# 70              7
# 88              3
# ...           ...
# 1363            5
# 1403            7
# 1439            6
# 1444            1
# 1456            5
#
# [186 rows x 7 columns]

# %%
#index() 函数用于从列表中找出某个值第一个匹配项的索引位置
#drop 刪除資料
df21_30=df3.drop(labels=df3[cond3].index)
df21_30
# Out:
#       LotFrontage  MSSubClass  MasVnrArea  MoSold  OpenPorchSF  OverallCond  \
# 0            65.0           5       196.0       2           61            5
# 1            80.0           0         0.0       5            0            8
# 2            68.0           5       162.0       9           42            5
# 3            60.0           6         0.0       2           35            5
# 4            84.0           5       350.0      12           84            5
# ...           ...         ...         ...     ...          ...          ...
# 1452         21.0          13         0.0      12            0            5
# 1453         21.0          13         0.0       6           34            5
# 1454         21.0          13         0.0       6            0            7
# 1455         21.0          13         0.0       4           24            5
# 1458         74.0           5        94.0      11           48            5
#
#       OverallQual
# 0               7
# 1               6
# 2               7
# 3               7
# 4               8
# ...           ...
# 1452            4
# 1453            4
# 1454            4
# 1455            4
# 1458            7
#
# [2559 rows x 7 columns]

# %%
#去除離峰值，未去除離峰值
df21_30.describe(),df3.describe()
# Out:
# (       LotFrontage   MSSubClass   MasVnrArea       MoSold  OpenPorchSF  \
#  count  2131.000000  2559.000000  2537.000000  2559.000000  2559.000000
#  mean     67.838104     4.284095    86.674024     6.186792    41.953107
#  std      20.256954     4.388238   138.735140     2.689184    54.624865
#  min      21.000000     0.000000     0.000000     1.000000     0.000000
#  25%      58.000000     0.000000     0.000000     4.000000     0.000000
#  50%      68.000000     4.000000     0.000000     6.000000    24.000000
#  75%      80.000000     6.000000   150.000000     8.000000    65.000000
#  max     138.000000    15.000000   640.000000    12.000000   250.000000
#
#         OverallCond  OverallQual
#  count  2559.000000  2559.000000
#  mean      5.550996     6.045721
#  std       1.003336     1.340365
#  min       3.000000     2.000000
#  25%       5.000000     5.000000
#  50%       5.000000     6.000000
#  75%       6.000000     7.000000
#  max       8.000000    10.000000  ,
#         LotFrontage   MSSubClass   MasVnrArea       MoSold  OpenPorchSF  \
#  count  2433.000000  2919.000000  2896.000000  2919.000000  2919.000000
#  mean     69.305795     4.266530   102.201312     6.213087    47.486811
#  std      23.344905     4.344907   179.334253     2.714762    67.575493
#  min      21.000000     0.000000     0.000000     1.000000     0.000000
#  25%      59.000000     0.000000     0.000000     4.000000     0.000000
#  50%      68.000000     4.000000     0.000000     6.000000    26.000000
#  75%      80.000000     6.000000   164.000000     8.000000    70.000000
#  max     313.000000    15.000000  1600.000000    12.000000   742.000000
#
#         OverallCond  OverallQual
#  count  2919.000000  2919.000000
#  mean      5.564577     6.089072
#  std       1.113131     1.409947
#  min       1.000000     1.000000
#  25%       5.000000     5.000000
#  50%       5.000000     6.000000
#  75%       6.000000     7.000000
#  max       9.000000    10.000000  )

# %%
df21_30.hist(),df3.hist()
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027730334988>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773033FBC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773035BCC8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027730394348>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277303C7988>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277303F7FC8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277304329C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027730467748>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773046F5C8>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027730548B48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277304F7AC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773060A908>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027730642A48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773067AB08>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277306B2C08>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277306EBD48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027730724E48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773072EA48>]],
#        dtype=object))

# %% [markdown]
# ### df4 31-40筆資料

# %%
df4 = num.iloc[:,30:40]
df4
#
#ScreenPorch: Screen porch area in square feet
#TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#TotalBsmtSF: Total square feet of basement area
#WoodDeckSF: Wood deck area in square feet
#YearBuilt: Original construction date
#YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#YrSold: Year Sold (YYYY)
# Out:
#       SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0      208500.0            0             8        856.0           0
# 1      181500.0            0             6       1262.0         298
# 2      223500.0            0             6        920.0           0
# 3      140000.0            0             7        756.0           0
# 4      250000.0            0             9       1145.0         192
# ...         ...          ...           ...          ...         ...
# 1454        NaN            0             5        546.0           0
# 1455        NaN            0             6        546.0           0
# 1456        NaN            0             7       1224.0         474
# 1457        NaN            0             6        912.0          80
# 1458        NaN            0             9        996.0         190
#
#       YearBuilt  YearRemodAdd  YrSold
# 0          2003          2003    2008
# 1          1976          1976    2007
# 2          2001          2002    2008
# 3          1915          1970    2006
# 4          2000          2000    2008
# ...         ...           ...     ...
# 1454       1970          1970    2006
# 1455       1970          1970    2006
# 1456       1960          1996    2006
# 1457       1992          1992    2006
# 1458       1993          1994    2006
#
# [2919 rows x 8 columns]

# %%
df4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002773091CF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277319824C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277319ADE88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277319DF0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731A14A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731A4E488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027731A7C948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731AB1A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731ABC688>]],
#       dtype=object)

# %%
df4.describe()
# Out:
#            SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF   WoodDeckSF  \
# count    1460.000000  2919.000000   2919.000000  2918.000000  2919.000000
# mean   180921.195890    16.062350      6.451524  1051.777587    93.709832
# std     79442.502883    56.184365      1.569379   440.766258   126.526589
# min     34900.000000     0.000000      2.000000     0.000000     0.000000
# 25%    129975.000000     0.000000      5.000000   793.000000     0.000000
# 50%    163000.000000     0.000000      6.000000   989.500000     0.000000
# 75%    214000.000000     0.000000      7.000000  1302.000000   168.000000
# max    755000.000000   576.000000     15.000000  6110.000000  1424.000000
#
#          YearBuilt  YearRemodAdd       YrSold
# count  2919.000000   2919.000000  2919.000000
# mean   1971.312778   1984.264474  2007.792737
# std      30.291442     20.894344     1.314964
# min    1872.000000   1950.000000  2006.000000
# 25%    1953.500000   1965.000000  2007.000000
# 50%    1973.000000   1993.000000  2008.000000
# 75%    2001.000000   2004.000000  2009.000000
# max    2010.000000   2010.000000  2010.000000

# %% [markdown]
# ### 去除離峰值

# %%
std = df4.std()
mean = df4.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (SalePrice      -57406.312758
#  ScreenPorch      -152.490745
#  TotRmsAbvGrd        1.743387
#  TotalBsmtSF      -270.521187
#  WoodDeckSF       -285.869936
#  YearBuilt        1880.438454
#  YearRemodAdd     1921.581441
#  YrSold           2003.847844
#  dtype: float64, SalePrice       419248.704539
#  ScreenPorch        184.615445
#  TotRmsAbvGrd        11.159662
#  TotalBsmtSF       2374.076362
#  WoodDeckSF         473.289600
#  YearBuilt         2062.187103
#  YearRemodAdd      2046.947507
#  YrSold            2011.737631
#  dtype: float64)

# %%
cond4=((df4>ma) | (df4<mi))
cond4
# Out:
#       SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0         False        False         False        False       False
# 1         False        False         False        False       False
# 2         False        False         False        False       False
# 3         False        False         False        False       False
# 4         False        False         False        False       False
# ...         ...          ...           ...          ...         ...
# 1454      False        False         False        False       False
# 1455      False        False         False        False       False
# 1456      False        False         False        False        True
# 1457      False        False         False        False       False
# 1458      False        False         False        False       False
#
#       YearBuilt  YearRemodAdd  YrSold
# 0         False         False   False
# 1         False         False   False
# 2         False         False   False
# 3         False         False   False
# 4         False         False   False
# ...         ...           ...     ...
# 1454      False         False   False
# 1455      False         False   False
# 1456      False         False   False
# 1457      False         False   False
# 1458      False         False   False
#
# [2919 rows x 8 columns]

# %%
cond4.sum()
# Out:
# SalePrice        22
# ScreenPorch     107
# TotRmsAbvGrd     19
# TotalBsmtSF      21
# WoodDeckSF       42
# YearBuilt         8
# YearRemodAdd      0
# YrSold            0
# dtype: int64

# %%
#any()用法: 是否有元素為true
cond4=cond4.any(axis=1)

# %%
#離峰值
df4[cond4]
# Out:
#       SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 46     239686.0          198             6       1434.0         168
# 53     385000.0            0             5       1842.0         857
# 58     438780.0            0            10       1410.0         192
# 64     219500.0            0             8       1057.0         576
# 72     185000.0          291             7        832.0           0
# ...         ...          ...           ...          ...         ...
# 1362        NaN            0             7       1836.0         684
# 1364        NaN          348             7          0.0           0
# 1415        NaN            0             6        624.0         530
# 1425        NaN          192             9       1168.0           0
# 1456        NaN            0             7       1224.0         474
#
#       YearBuilt  YearRemodAdd  YrSold
# 46         2003          2003    2009
# 53         1981          1987    2006
# 58         2006          2006    2006
# 64         1997          1998    2009
# 72         1998          1998    2009
# ...         ...           ...     ...
# 1362       1935          1990    2006
# 1364       1952          2002    2006
# 1415       1926          1997    2006
# 1425       1950          1963    2006
# 1456       1960          1996    2006
#
# [197 rows x 8 columns]

# %%
#index() 函数用于从列表中找出某个值第一个匹配项的索引位置
#drop 刪除資料
df31_38=df4.drop(labels=df4[cond4].index)
df31_38
# Out:
#       SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0      208500.0            0             8        856.0           0
# 1      181500.0            0             6       1262.0         298
# 2      223500.0            0             6        920.0           0
# 3      140000.0            0             7        756.0           0
# 4      250000.0            0             9       1145.0         192
# ...         ...          ...           ...          ...         ...
# 1453        NaN            0             5        546.0           0
# 1454        NaN            0             5        546.0           0
# 1455        NaN            0             6        546.0           0
# 1457        NaN            0             6        912.0          80
# 1458        NaN            0             9        996.0         190
#
#       YearBuilt  YearRemodAdd  YrSold
# 0          2003          2003    2008
# 1          1976          1976    2007
# 2          2001          2002    2008
# 3          1915          1970    2006
# 4          2000          2000    2008
# ...         ...           ...     ...
# 1453       1970          1970    2006
# 1454       1970          1970    2006
# 1455       1970          1970    2006
# 1457       1992          1992    2006
# 1458       1993          1994    2006
#
# [2532 rows x 8 columns]

# %%
df31_38.describe(),df4.describe()
# Out:
# (           SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF   WoodDeckSF  \
#  count    1266.000000  2532.000000   2532.000000  2531.000000  2532.000000
#  mean   173368.904423     7.118088      6.353476  1027.257606    87.858215
#  std     66807.490823    31.289498      1.463724   399.008023   110.942320
#  min     37900.000000     0.000000      2.000000     0.000000     0.000000
#  25%    128050.000000     0.000000      5.000000   784.000000     0.000000
#  50%    158950.000000     0.000000      6.000000   978.000000     0.000000
#  75%    206225.000000     0.000000      7.000000  1275.000000   168.000000
#  max    415298.000000   184.000000     11.000000  2320.000000   468.000000
#
#           YearBuilt  YearRemodAdd       YrSold
#  count  2532.000000   2532.000000  2532.000000
#  mean   1971.537125   1984.297393  2007.799368
#  std      30.019035     20.951422     1.319111
#  min    1885.000000   1950.000000  2006.000000
#  25%    1953.000000   1965.000000  2007.000000
#  50%    1973.000000   1993.000000  2008.000000
#  75%    2001.000000   2004.000000  2009.000000
#  max    2010.000000   2010.000000  2010.000000  ,
#             SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF   WoodDeckSF  \
#  count    1460.000000  2919.000000   2919.000000  2918.000000  2919.000000
#  mean   180921.195890    16.062350      6.451524  1051.777587    93.709832
#  std     79442.502883    56.184365      1.569379   440.766258   126.526589
#  min     34900.000000     0.000000      2.000000     0.000000     0.000000
#  25%    129975.000000     0.000000      5.000000   793.000000     0.000000
#  50%    163000.000000     0.000000      6.000000   989.500000     0.000000
#  75%    214000.000000     0.000000      7.000000  1302.000000   168.000000
#  max    755000.000000   576.000000     15.000000  6110.000000  1424.000000
#
#           YearBuilt  YearRemodAdd       YrSold
#  count  2919.000000   2919.000000  2919.000000
#  mean   1971.312778   1984.264474  2007.792737
#  std      30.291442     20.894344     1.314964
#  min    1872.000000   1950.000000  2006.000000
#  25%    1953.500000   1965.000000  2007.000000
#  50%    1973.000000   1993.000000  2008.000000
#  75%    2001.000000   2004.000000  2009.000000
#  max    2010.000000   2010.000000  2010.000000  )

# %%
df31_38.hist(),df4.hist()
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027731CD6DC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731CFC848>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731D20A88>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027731D58108>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731D8B748>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731DBDD88>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027731DF7408>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731E29A48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731E30888>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027731F5F348>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731D438C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027731FE8B08>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027732021BC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773205AD08>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027732092E48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277320CAF48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027732109088>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773210FC48>]],
#        dtype=object))

# %% [markdown]
# ### 合併數字欄位

# %%
num = df1_10.join(df11_20) 
num = num.join(df21_30)
num = num.join(df31_38)
num
# Out:
#       1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtFinSF1  BsmtFullBath  BsmtUnfSF  \
# 0          856       854             3       706.0           1.0      150.0
# 0          856       854             3       706.0           1.0      150.0
# 0          856       854             3       706.0           1.0      150.0
# 0          856       854             3       706.0           1.0      150.0
# 0          856       854             3       706.0           1.0      150.0
# ...        ...       ...           ...         ...           ...        ...
# 1458       996      1004             3       758.0           0.0      238.0
# 1458       996      1004             3       758.0           0.0      238.0
# 1458       996      1004             3       758.0           0.0      238.0
# 1458       996      1004             3       758.0           0.0      238.0
# 1459      1256         0             3       830.0           1.0      136.0
#
#       Fireplaces  FullBath  GarageArea  GarageCars  ...  OverallCond  \
# 0            0.0       2.0       548.0         2.0  ...          5.0
# 0            0.0       2.0       548.0         2.0  ...          5.0
# 0            0.0       2.0       548.0         2.0  ...          6.0
# 0            0.0       2.0       548.0         2.0  ...          6.0
# 0            0.0       1.0       730.0         1.0  ...          5.0
# ...          ...       ...         ...         ...  ...          ...
# 1458         1.0       2.0       650.0         3.0  ...          6.0
# 1458         1.0       2.0       650.0         3.0  ...          6.0
# 1458         1.0       2.0       650.0         3.0  ...          5.0
# 1458         1.0       2.0       650.0         3.0  ...          5.0
# 1459         0.0       1.0       276.0         1.0  ...          6.0
#
#       OverallQual  SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  \
# 0             7.0   208500.0          0.0           8.0        856.0
# 0             7.0        NaN        120.0           5.0        882.0
# 0             5.0   208500.0          0.0           8.0        856.0
# 0             5.0        NaN        120.0           5.0        882.0
# 0             7.0   208500.0          0.0           8.0        856.0
# ...           ...        ...          ...           ...          ...
# 1458          5.0   142125.0          0.0           5.0       1078.0
# 1458          5.0        NaN          0.0           9.0        996.0
# 1458          7.0   142125.0          0.0           5.0       1078.0
# 1458          7.0        NaN          0.0           9.0        996.0
# 1459          5.0        NaN          NaN           NaN          NaN
#
#       WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0            0.0     2003.0        2003.0  2008.0
# 0          140.0     1961.0        1961.0  2010.0
# 0            0.0     2003.0        2003.0  2008.0
# 0          140.0     1961.0        1961.0  2010.0
# 0            0.0     2003.0        2003.0  2008.0
# ...          ...        ...           ...     ...
# 1458       366.0     1950.0        1996.0  2010.0
# 1458       190.0     1993.0        1994.0  2006.0
# 1458       366.0     1950.0        1996.0  2010.0
# 1458       190.0     1993.0        1994.0  2006.0
# 1459         NaN        NaN           NaN     NaN
#
# [18587 rows x 31 columns]

# %% [markdown]
# ### 處理object 資料

# %%
#obj: dtype為object
obj = data.select_dtypes(include=['object'])
obj
# Out:
#      Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0      NaN     1Fam       TA           No          GLQ          Unf       Gd
# 1      NaN     1Fam       TA           Gd          ALQ          Unf       Gd
# 2      NaN     1Fam       TA           Mn          GLQ          Unf       Gd
# 3      NaN     1Fam       Gd           No          ALQ          Unf       TA
# 4      NaN     1Fam       TA           Av          GLQ          Unf       Gd
# ...    ...      ...      ...          ...          ...          ...      ...
# 1454   NaN    Twnhs       TA           No          Unf          Unf       TA
# 1455   NaN   TwnhsE       TA           No          Rec          Unf       TA
# 1456   NaN     1Fam       TA           No          ALQ          Unf       TA
# 1457   NaN     1Fam       TA           Av          GLQ          Unf       Gd
# 1458   NaN     1Fam       TA           Av          LwQ          Unf       Gd
#
#      CentralAir Condition1 Condition2  ... MiscFeature Neighborhood  \
# 0             Y       Norm       Norm  ...         NaN      CollgCr
# 1             Y      Feedr       Norm  ...         NaN      Veenker
# 2             Y       Norm       Norm  ...         NaN      CollgCr
# 3             Y       Norm       Norm  ...         NaN      Crawfor
# 4             Y       Norm       Norm  ...         NaN      NoRidge
# ...         ...        ...        ...  ...         ...          ...
# 1454          Y       Norm       Norm  ...         NaN      MeadowV
# 1455          Y       Norm       Norm  ...         NaN      MeadowV
# 1456          Y       Norm       Norm  ...         NaN      Mitchel
# 1457          Y       Norm       Norm  ...        Shed      Mitchel
# 1458          Y       Norm       Norm  ...         NaN      Mitchel
#
#      PavedDrive PoolQC RoofMatl RoofStyle SaleCondition SaleType Street  \
# 0             Y    NaN  CompShg     Gable        Normal       WD   Pave
# 1             Y    NaN  CompShg     Gable        Normal       WD   Pave
# 2             Y    NaN  CompShg     Gable        Normal       WD   Pave
# 3             Y    NaN  CompShg     Gable       Abnorml       WD   Pave
# 4             Y    NaN  CompShg     Gable        Normal       WD   Pave
# ...         ...    ...      ...       ...           ...      ...    ...
# 1454          Y    NaN  CompShg     Gable        Normal       WD   Pave
# 1455          Y    NaN  CompShg     Gable       Abnorml       WD   Pave
# 1456          Y    NaN  CompShg     Gable       Abnorml       WD   Pave
# 1457          Y    NaN  CompShg     Gable        Normal       WD   Pave
# 1458          Y    NaN  CompShg     Gable        Normal       WD   Pave
#
#      Utilities
# 0       AllPub
# 1       AllPub
# 2       AllPub
# 3       AllPub
# 4       AllPub
# ...        ...
# 1454    AllPub
# 1455    AllPub
# 1456    AllPub
# 1457    AllPub
# 1458    AllPub
#
# [2919 rows x 43 columns]

# %%
obj.describe()
# Out:
#        Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# count    198     2919     2837         2837         2840         2839
# unique     2        5        4            4            6            6
# top     Grvl     1Fam       TA           No          Unf          Unf
# freq     120     2425     2606         1904          851         2493
#
#        BsmtQual CentralAir Condition1 Condition2  ... MiscFeature  \
# count      2838       2919       2919       2919  ...         105
# unique        4          2          9          8  ...           4
# top          TA          Y       Norm       Norm  ...        Shed
# freq       1283       2723       2511       2889  ...          95
#
#        Neighborhood PavedDrive PoolQC RoofMatl RoofStyle SaleCondition  \
# count          2919       2919     10     2919      2919          2919
# unique           25          3      3        8         6             6
# top           NAmes          Y     Ex  CompShg     Gable        Normal
# freq            443       2641      4     2876      2310          2402
#
#        SaleType Street Utilities
# count      2918   2919      2917
# unique        9      2         2
# top          WD   Pave    AllPub
# freq       2525   2907      2916
#
# [4 rows x 43 columns]

# %% [markdown]
# ### 處理object 1-10 筆資料

# %%
o1 = obj.iloc[:,0:10]
o1
# Out:
#      Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0        2        0        3            1            6            1        4
# 1        2        0        3            4            5            1        4
# 2        2        0        3            2            6            1        4
# 3        2        0        4            1            5            1        3
# 4        2        0        3            3            6            1        4
# ...    ...      ...      ...          ...          ...          ...      ...
# 1454     2        3        3            1            1            1        3
# 1455     2        1        3            1            3            1        3
# 1456     2        0        3            1            5            1        3
# 1457     2        0        3            3            6            1        4
# 1458     2        0        3            3            2            1        4
#
#      CentralAir Condition1 Condition2
# 0             1          2          2
# 1             1          1          2
# 2             1          2          2
# 3             1          2          2
# 4             1          2          2
# ...         ...        ...        ...
# 1454          1          2          2
# 1455          1          2          2
# 1456          1          2          2
# 1457          1          2          2
# 1458          1          2          2
#
# [2919 rows x 10 columns]

# %%
#將Alley改為數值
o1.loc[o1['Alley'] =='Grvl','Alley']=0
o1.loc[o1['Alley'] =='Pave','Alley']=1
o1.loc[o1['Alley'].isnull(),'Alley']=2
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#將BldgType改為數值
o1.loc[o1['BldgType'] =='1Fam','BldgType']=0
o1.loc[o1['BldgType'] =='TwnhsE','BldgType']=1
o1.loc[o1['BldgType'] =='Duplex','BldgType']=2
o1.loc[o1['BldgType'] =='Twnhs','BldgType']=3
o1.loc[o1['BldgType'] =='2fmCon','BldgType']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將BsmtCond改為數值
o1.loc[o1['BsmtCond'] =='Po','BsmtCond']=1
o1.loc[o1['BsmtCond'] =='Fa','BsmtCond']=2
o1.loc[o1['BsmtCond'] =='TA','BsmtCond']=3
o1.loc[o1['BsmtCond'] =='Gd','BsmtCond']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#將BsmtExposure改為數值
o1.loc[o1['BsmtExposure'] =='NA','BsmtExposure']=0
o1.loc[o1['BsmtExposure'] =='No','BsmtExposure']=1
o1.loc[o1['BsmtExposure'] =='Mn','BsmtExposure']=2
o1.loc[o1['BsmtExposure'] =='Av','BsmtExposure']=3
o1.loc[o1['BsmtExposure'] =='Gd','BsmtExposure']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將BsmtFinType1改為數值
o1.loc[o1['BsmtFinType1'] =='NA','BsmtFinType1']=0
o1.loc[o1['BsmtFinType1'] =='Unf','BsmtFinType1']=1
o1.loc[o1['BsmtFinType1'] =='LwQ','BsmtFinType1']=2
o1.loc[o1['BsmtFinType1'] =='Rec','BsmtFinType1']=3
o1.loc[o1['BsmtFinType1'] =='BLQ','BsmtFinType1']=4
o1.loc[o1['BsmtFinType1'] =='ALQ','BsmtFinType1']=5
o1.loc[o1['BsmtFinType1'] =='GLQ','BsmtFinType1']=6
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將BsmtFinType2改為數值
o1.loc[o1['BsmtFinType2'] =='NA','BsmtFinType2']=0
o1.loc[o1['BsmtFinType2'] =='Unf','BsmtFinType2']=1
o1.loc[o1['BsmtFinType2'] =='LwQ','BsmtFinType2']=2
o1.loc[o1['BsmtFinType2'] =='Rec','BsmtFinType2']=3
o1.loc[o1['BsmtFinType2'] =='BLQ','BsmtFinType2']=4
o1.loc[o1['BsmtFinType2'] =='ALQ','BsmtFinType2']=5
o1.loc[o1['BsmtFinType2'] =='GLQ','BsmtFinType2']=6
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將BsmtQual改為數值
o1.loc[o1['BsmtQual'] =='Po','BsmtQual']=1
o1.loc[o1['BsmtQual'] =='Fa','BsmtQual']=2
o1.loc[o1['BsmtQual'] =='TA','BsmtQual']=3
o1.loc[o1['BsmtQual'] =='Gd','BsmtQual']=4
o1.loc[o1['BsmtQual'] =='Ex','BsmtQual']=5
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將CentralAir改為數值
o1.loc[o1['CentralAir'] =='N','CentralAir']=0
o1.loc[o1['CentralAir'] =='Y','CentralAir']=1
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#將Condition1改為數值
o1.loc[o1['Condition1'] =='Artery','Condition1']=0
o1.loc[o1['Condition1'] =='Feedr','Condition1']=1
o1.loc[o1['Condition1'] =='Norm','Condition1']=2
o1.loc[o1['Condition1'] =='RRNn','Condition1']=3
o1.loc[o1['Condition1'] =='RRAn','Condition1']=4
o1.loc[o1['Condition1'] =='PosN','Condition1']=5
o1.loc[o1['Condition1'] =='PosA','Condition1']=6
o1.loc[o1['Condition1'] =='RRNe','Condition1']=7
o1.loc[o1['Condition1'] =='RRAe','Condition1']=8
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#將Condition2改為數值
o1.loc[o1['Condition2'] =='Artery','Condition2']=0
o1.loc[o1['Condition2'] =='Feedr','Condition2']=1
o1.loc[o1['Condition2'] =='Norm','Condition2']=2
o1.loc[o1['Condition2'] =='RRNn','Condition2']=3
o1.loc[o1['Condition2'] =='RRAn','Condition2']=4
o1.loc[o1['Condition2'] =='PosN','Condition2']=5
o1.loc[o1['Condition2'] =='PosA','Condition2']=6
o1.loc[o1['Condition2'] =='RRNe','Condition2']=7
o1.loc[o1['Condition2'] =='RRAe','Condition2']=8
o1
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#      Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0        2        0        3            1            6            1        4
# 1        2        0        3            4            5            1        4
# 2        2        0        3            2            6            1        4
# 3        2        0        4            1            5            1        3
# 4        2        0        3            3            6            1        4
# ...    ...      ...      ...          ...          ...          ...      ...
# 1454     2        3        3            1            1            1        3
# 1455     2        1        3            1            3            1        3
# 1456     2        0        3            1            5            1        3
# 1457     2        0        3            3            6            1        4
# 1458     2        0        3            3            2            1        4
#
#      CentralAir Condition1 Condition2
# 0             1          2          2
# 1             1          1          2
# 2             1          2          2
# 3             1          2          2
# 4             1          2          2
# ...         ...        ...        ...
# 1454          1          2          2
# 1455          1          2          2
# 1456          1          2          2
# 1457          1          2          2
# 1458          1          2          2
#
# [2919 rows x 10 columns]

# %%
o1 = o1.astype(float)
o1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000277339AE7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277339BDC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277339D3BC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027733A0E248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733A41888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733A70EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277339AA048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733AC4148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733ACAD08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027733B03EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733B6E488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733BA85C8>]],
#       dtype=object)

# %%
o1.astype(float).describe()
# Out:
#              Alley     BldgType     BsmtCond  BsmtExposure  BsmtFinType1  \
# count  2919.000000  2919.000000  2837.000000   2837.000000   2840.000000
# mean      1.891059     0.336074     3.002820      1.670779      3.640141
# std       0.423503     0.866186     0.294506      1.048625      2.057660
# min       0.000000     0.000000     1.000000      1.000000      1.000000
# 25%       2.000000     0.000000     3.000000      1.000000      1.000000
# 50%       2.000000     0.000000     3.000000      1.000000      4.000000
# 75%       2.000000     0.000000     3.000000      2.000000      6.000000
# max       2.000000     4.000000     4.000000      4.000000      6.000000
#
#        BsmtFinType2     BsmtQual   CentralAir   Condition1   Condition2
# count   2839.000000  2838.000000  2919.000000  2919.000000  2919.000000
# mean       1.309616     3.576815     0.932854     2.053443     2.005139
# std        0.943963     0.698645     0.250318     0.936954     0.244839
# min        1.000000     2.000000     0.000000     0.000000     0.000000
# 25%        1.000000     3.000000     1.000000     2.000000     2.000000
# 50%        1.000000     4.000000     1.000000     2.000000     2.000000
# 75%        1.000000     4.000000     1.000000     2.000000     2.000000
# max        6.000000     5.000000     1.000000     8.000000     8.000000

# %%
std = o1.std()
mean = o1.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (Alley           0.620550
#  BldgType       -2.262484
#  BsmtCond        2.119301
#  BsmtExposure   -1.475097
#  BsmtFinType1   -2.532839
#  BsmtFinType2   -1.522274
#  BsmtQual        1.480879
#  CentralAir      0.181900
#  Condition1     -0.757420
#  Condition2      1.270622
#  dtype: float64, Alley           3.161567
#  BldgType        2.934632
#  BsmtCond        3.886339
#  BsmtExposure    4.816655
#  BsmtFinType1    9.813120
#  BsmtFinType2    4.141506
#  BsmtQual        5.672750
#  CentralAir      1.683808
#  Condition1      4.864305
#  Condition2      2.739656
#  dtype: float64)

# %%
cond5=((o1>ma) | (o1<mi))
cond5
# Out:
#       Alley  BldgType  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0     False     False     False         False         False         False
# 1     False     False     False         False         False         False
# 2     False     False     False         False         False         False
# 3     False     False      True         False         False         False
# 4     False     False     False         False         False         False
# ...     ...       ...       ...           ...           ...           ...
# 1454  False      True     False         False         False         False
# 1455  False     False     False         False         False         False
# 1456  False     False     False         False         False         False
# 1457  False     False     False         False         False         False
# 1458  False     False     False         False         False         False
#
#       BsmtQual  CentralAir  Condition1  Condition2
# 0        False       False       False       False
# 1        False       False       False       False
# 2        False       False       False       False
# 3        False       False       False       False
# 4        False       False       False       False
# ...        ...         ...         ...         ...
# 1454     False       False       False       False
# 1455     False       False       False       False
# 1456     False       False       False       False
# 1457     False       False       False       False
# 1458     False       False       False       False
#
# [2919 rows x 10 columns]

# %%
cond5.sum()
# Out:
# Alley           120
# BldgType        158
# BsmtCond        231
# BsmtExposure      0
# BsmtFinType1      0
# BsmtFinType2     86
# BsmtQual          0
# CentralAir      196
# Condition1       93
# Condition2       30
# dtype: int64

# %%
#any()用法: 是否有元素為true
cond5=cond5.any(axis=1)

# %%
o1[cond5]
# Out:
#       Alley  BldgType  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 3       2.0       0.0       4.0           1.0           5.0           1.0
# 7       2.0       0.0       3.0           2.0           5.0           4.0
# 9       2.0       4.0       3.0           1.0           6.0           1.0
# 18      2.0       0.0       3.0           1.0           6.0           1.0
# 21      0.0       0.0       3.0           1.0           1.0           1.0
# ...     ...       ...       ...           ...           ...           ...
# 1442    2.0       0.0       4.0           3.0           6.0           1.0
# 1449    2.0       3.0       3.0           3.0           6.0           1.0
# 1452    2.0       3.0       3.0           1.0           3.0           1.0
# 1453    2.0       3.0       3.0           1.0           1.0           1.0
# 1454    2.0       3.0       3.0           1.0           1.0           1.0
#
#       BsmtQual  CentralAir  Condition1  Condition2
# 3          3.0         1.0         2.0         2.0
# 7          4.0         1.0         5.0         2.0
# 9          3.0         1.0         0.0         0.0
# 18         3.0         1.0         8.0         2.0
# 21         3.0         1.0         2.0         2.0
# ...        ...         ...         ...         ...
# 1442       5.0         1.0         2.0         2.0
# 1449       4.0         1.0         2.0         2.0
# 1452       3.0         1.0         2.0         2.0
# 1453       3.0         1.0         2.0         2.0
# 1454       3.0         1.0         2.0         2.0
#
# [744 rows x 10 columns]

# %%
o1_10=o1.drop(labels=o1[cond5].index)
o1_10
# Out:
#       Alley  BldgType  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0       2.0       0.0       3.0           1.0           6.0           1.0
# 1       2.0       0.0       3.0           4.0           5.0           1.0
# 2       2.0       0.0       3.0           2.0           6.0           1.0
# 4       2.0       0.0       3.0           3.0           6.0           1.0
# 5       2.0       0.0       3.0           1.0           6.0           1.0
# ...     ...       ...       ...           ...           ...           ...
# 1450    2.0       1.0       3.0           1.0           3.0           1.0
# 1451    2.0       0.0       3.0           3.0           3.0           4.0
# 1455    2.0       1.0       3.0           1.0           3.0           1.0
# 1456    2.0       0.0       3.0           1.0           5.0           1.0
# 1458    2.0       0.0       3.0           3.0           2.0           1.0
#
#       BsmtQual  CentralAir  Condition1  Condition2
# 0          4.0         1.0         2.0         2.0
# 1          4.0         1.0         1.0         2.0
# 2          4.0         1.0         2.0         2.0
# 4          4.0         1.0         2.0         2.0
# 5          4.0         1.0         2.0         2.0
# ...        ...         ...         ...         ...
# 1450       3.0         1.0         2.0         2.0
# 1451       3.0         1.0         2.0         2.0
# 1455       3.0         1.0         2.0         2.0
# 1456       3.0         1.0         2.0         2.0
# 1458       4.0         1.0         2.0         2.0
#
# [1645 rows x 10 columns]

# %%
o1_10.describe(),o1.describe()
# Out:
# (             Alley     BldgType  BsmtCond  BsmtExposure  BsmtFinType1  \
#  count  1645.000000  1645.000000    1609.0   1610.000000   1612.000000
#  mean      1.978116     0.159271       3.0      1.716149      3.815757
#  std       0.146351     0.444123       0.0      1.067423      2.059675
#  min       1.000000     0.000000       3.0      1.000000      1.000000
#  25%       2.000000     0.000000       3.0      1.000000      1.000000
#  50%       2.000000     0.000000       3.0      1.000000      4.000000
#  75%       2.000000     0.000000       3.0      3.000000      6.000000
#  max       2.000000     2.000000       3.0      4.000000      6.000000
#
#         BsmtFinType2     BsmtQual  CentralAir   Condition1  Condition2
#  count   1612.000000  1612.000000      1645.0  1645.000000      1645.0
#  mean       1.192928     3.655087         1.0     1.935562         2.0
#  std        0.631768     0.678767         0.0     0.450175         0.0
#  min        1.000000     2.000000         1.0     0.000000         2.0
#  25%        1.000000     3.000000         1.0     2.000000         2.0
#  50%        1.000000     4.000000         1.0     2.000000         2.0
#  75%        1.000000     4.000000         1.0     2.000000         2.0
#  max        4.000000     5.000000         1.0     4.000000         2.0  ,
#               Alley     BldgType     BsmtCond  BsmtExposure  BsmtFinType1  \
#  count  2919.000000  2919.000000  2837.000000   2837.000000   2840.000000
#  mean      1.891059     0.336074     3.002820      1.670779      3.640141
#  std       0.423503     0.866186     0.294506      1.048625      2.057660
#  min       0.000000     0.000000     1.000000      1.000000      1.000000
#  25%       2.000000     0.000000     3.000000      1.000000      1.000000
#  50%       2.000000     0.000000     3.000000      1.000000      4.000000
#  75%       2.000000     0.000000     3.000000      2.000000      6.000000
#  max       2.000000     4.000000     4.000000      4.000000      6.000000
#
#         BsmtFinType2     BsmtQual   CentralAir   Condition1   Condition2
#  count   2839.000000  2838.000000  2919.000000  2919.000000  2919.000000
#  mean       1.309616     3.576815     0.932854     2.053443     2.005139
#  std        0.943963     0.698645     0.250318     0.936954     0.244839
#  min        1.000000     2.000000     0.000000     0.000000     0.000000
#  25%        1.000000     3.000000     1.000000     2.000000     2.000000
#  50%        1.000000     4.000000     1.000000     2.000000     2.000000
#  75%        1.000000     4.000000     1.000000     2.000000     2.000000
#  max        6.000000     5.000000     1.000000     8.000000     8.000000  )

# %%
o1_10.hist(),o1.hist()
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027733DEA7C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733DF8248>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733E15308>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027733E4B308>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733E82D08>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733EBFE88>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027733EF5088>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733F2AA48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733F36648>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027733F6F848>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027733FD3D88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773400DF48>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027734047188>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277340714C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277341D6848>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002773420E988>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027734246A88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027734280B48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277342B7C88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277342EFDC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277342FA9C8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027734332B88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002773439E0C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277343D4288>]],
#        dtype=object))

# %% [markdown]
# ### o2 object 11-20筆資料

# %%
o2 = obj.iloc[:,10:20]
o2
# Out:
#      Electrical ExterCond ExterQual Exterior1st Exterior2nd  Fence  \
# 0         SBrkr        TA        Gd     VinylSd     VinylSd    NaN
# 1         SBrkr        TA        TA     MetalSd     MetalSd    NaN
# 2         SBrkr        TA        Gd     VinylSd     VinylSd    NaN
# 3         SBrkr        TA        TA     Wd Sdng     Wd Shng    NaN
# 4         SBrkr        TA        Gd     VinylSd     VinylSd    NaN
# ...         ...       ...       ...         ...         ...    ...
# 1454      SBrkr        TA        TA     CemntBd     CmentBd    NaN
# 1455      SBrkr        TA        TA     CemntBd     CmentBd    NaN
# 1456      SBrkr        TA        TA     VinylSd     VinylSd    NaN
# 1457      SBrkr        TA        TA     HdBoard     Wd Shng  MnPrv
# 1458      SBrkr        TA        TA     HdBoard     HdBoard    NaN
#
#      FireplaceQu Foundation Functional GarageCond
# 0            NaN      PConc        Typ         TA
# 1             TA     CBlock        Typ         TA
# 2             TA      PConc        Typ         TA
# 3             Gd     BrkTil        Typ         TA
# 4             TA      PConc        Typ         TA
# ...          ...        ...        ...        ...
# 1454         NaN     CBlock        Typ        NaN
# 1455         NaN     CBlock        Typ         TA
# 1456          TA     CBlock        Typ         TA
# 1457         NaN      PConc        Typ        NaN
# 1458          TA      PConc        Typ         TA
#
# [2919 rows x 10 columns]

# %%
o2.describe()
# Out:
#        Electrical ExterCond ExterQual Exterior1st Exterior2nd  Fence  \
# count        2918      2919      2919        2918        2918    571
# unique          5         5         4          15          16      4
# top         SBrkr        TA        TA     VinylSd     VinylSd  MnPrv
# freq         2671      2538      1798        1025        1014    329
#
#        FireplaceQu Foundation Functional GarageCond
# count         1499       2919       2917       2760
# unique           5          6          7          5
# top             Gd      PConc        Typ         TA
# freq           744       1308       2717       2654

# %% [markdown]
# # 改成數字

# %%
#將Electrical改為數值
o2.loc[o2['Electrical'] =='SBrkr','Electrical']=0
o2.loc[o2['Electrical'] =='FuseA','Electrical']=1
o2.loc[o2['Electrical'] =='FuseF','Electrical']=2
o2.loc[o2['Electrical'] =='FuseP','Electrical']=3
o2.loc[o2['Electrical'] =='Mix','Electrical']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將ExterCond改為數值
o2.loc[o2['ExterCond'] =='Po','ExterCond']=0
o2.loc[o2['ExterCond'] =='Fa','ExterCond']=1
o2.loc[o2['ExterCond'] =='TA','ExterCond']=2
o2.loc[o2['ExterCond'] =='Gd','ExterCond']=3
o2.loc[o2['ExterCond'] =='Ex','ExterCond']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將ExterQual改為數值
o2.loc[o2['ExterQual'] =='Po','ExterQual']=0
o2.loc[o2['ExterQual'] =='Fa','ExterQual']=1
o2.loc[o2['ExterQual'] =='TA','ExterQual']=2
o2.loc[o2['ExterQual'] =='Gd','ExterQual']=3
o2.loc[o2['ExterQual'] =='Ex','ExterQual']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將Exterior1st改為數值
o2.loc[o2['Exterior1st'] =='AsbShng','Exterior1st']=0
o2.loc[o2['Exterior1st'] =='AsphShn','Exterior1st']=1
o2.loc[o2['Exterior1st'] =='BrkComm','Exterior1st']=2
o2.loc[o2['Exterior1st'] =='BrkFace','Exterior1st']=3
o2.loc[o2['Exterior1st'] =='CBlock','Exterior1st']=4
o2.loc[o2['Exterior1st'] =='CemntBd','Exterior1st']=5
o2.loc[o2['Exterior1st'] =='HdBoard','Exterior1st']=6
o2.loc[o2['Exterior1st'] =='ImStucc','Exterior1st']=7
o2.loc[o2['Exterior1st'] =='MetalSd','Exterior1st']=8
o2.loc[o2['Exterior1st'] =='Other','Exterior1st']=9
o2.loc[o2['Exterior1st'] =='Plywood','Exterior1st']=10
o2.loc[o2['Exterior1st'] =='PreCast','Exterior1st']=11
o2.loc[o2['Exterior1st'] =='Stone','Exterior1st']=12
o2.loc[o2['Exterior1st'] =='Stucco','Exterior1st']=13
o2.loc[o2['Exterior1st'] =='VinylSd','Exterior1st']=14
o2.loc[o2['Exterior1st'] =='Wd Sdng','Exterior1st']=15
o2.loc[o2['Exterior1st'] =='WdShing','Exterior1st']=16
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將Exterior2nd改為數值
o2.loc[o2['Exterior2nd'] =='AsbShng','Exterior2nd']=0
o2.loc[o2['Exterior2nd'] =='AsphShn','Exterior2nd']=1
o2.loc[o2['Exterior2nd'] =='Brk Cmn','Exterior2nd']=2
o2.loc[o2['Exterior2nd'] =='BrkFace','Exterior2nd']=3
o2.loc[o2['Exterior2nd'] =='CBlock','Exterior2nd']=4
o2.loc[o2['Exterior2nd'] =='CemntBd','Exterior2nd']=5
o2.loc[o2['Exterior2nd'] =='HdBoard','Exterior2nd']=6
o2.loc[o2['Exterior2nd'] =='ImStucc','Exterior2nd']=7
o2.loc[o2['Exterior2nd'] =='MetalSd','Exterior2nd']=8
o2.loc[o2['Exterior2nd'] =='Other','Exterior2nd']=9
o2.loc[o2['Exterior2nd'] =='Plywood','Exterior2nd']=10
o2.loc[o2['Exterior2nd'] =='PreCast','Exterior2nd']=11
o2.loc[o2['Exterior2nd'] =='Stone','Exterior2nd']=12
o2.loc[o2['Exterior2nd'] =='Stucco','Exterior2nd']=13
o2.loc[o2['Exterior2nd'] =='VinylSd','Exterior2nd']=14
o2.loc[o2['Exterior2nd'] =='Wd Sdng','Exterior2nd']=15
o2.loc[o2['Exterior2nd'] =='Wd Shng','Exterior2nd']=16
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將Fence改為數值
o2.loc[o2['Fence'].isnull(),'Fence']=0
o2.loc[o2['Fence'] =='GdPrv','Fence']=1
o2.loc[o2['Fence'] =='MnPrv','Fence']=2
o2.loc[o2['Fence'] =='GdWo','Fence']=3
o2.loc[o2['Fence'] =='MnWw','Fence']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將FireplaceQu改為數值
o2.loc[o2['FireplaceQu'].isnull(),'FireplaceQu']=0
o2.loc[o2['FireplaceQu'] =='Gd','FireplaceQu']=1
o2.loc[o2['FireplaceQu'] =='Ex','FireplaceQu']=2
o2.loc[o2['FireplaceQu'] =='Fa','FireplaceQu']=3
o2.loc[o2['FireplaceQu'] =='Po','FireplaceQu']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#將Foundation改為數值
o2.loc[o2['Foundation'] =='BrkTil','Foundation']=0
o2.loc[o2['Foundation'] =='CBlock','Foundation']=1
o2.loc[o2['Foundation'] =='PConc','Foundation']=2
o2.loc[o2['Foundation'] =='Slab','Foundation']=3
o2.loc[o2['Foundation'] =='Stone','Foundation']=4
o2.loc[o2['Foundation'] =='Wood','Foundation']=5
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#將Functional改為數值
o2.loc[o2['Functional'] =='Typ','Functional']=0
o2.loc[o2['Functional'] =='Min1','Functional']=1
o2.loc[o2['Functional'] =='Min2','Functional']=2
o2.loc[o2['Functional'] =='Mod','Functional']=3
o2.loc[o2['Functional'] =='Maj1','Functional']=4
o2.loc[o2['Functional'] =='Maj2','Functional']=5
o2.loc[o2['Functional'] =='Sev','Functional']=6
o2.loc[o2['Functional'] =='Sal','Functional']=7
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
#將GarageCond改為數值
o2.loc[o2['GarageCond'] =='NA','GarageCond']=0
o2.loc[o2['GarageCond'] =='Po','GarageCond']=1
o2.loc[o2['GarageCond'] =='Fa','GarageCond']=2
o2.loc[o2['GarageCond'] =='TA','GarageCond']=3
o2.loc[o2['GarageCond'] =='Gd','GarageCond']=4
o2.loc[o2['GarageCond'] =='Ex','GarageCond']=5
o2
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#      Electrical ExterCond ExterQual Exterior1st Exterior2nd Fence FireplaceQu  \
# 0             0         2         3          14          14     0           0
# 1             0         2         2           8           8     0           0
# 2             0         2         3          14          14     0           0
# 3             0         2         2          15          16     0           1
# 4             0         2         3          14          14     0           0
# ...         ...       ...       ...         ...         ...   ...         ...
# 1454          0         2         2           5           5     0           0
# 1455          0         2         2           5           5     0           0
# 1456          0         2         2          14          14     0           0
# 1457          0         2         2           6          16     2           0
# 1458          0         2         2           6           6     0           0
#
#      Foundation Functional GarageCond
# 0             2          0          3
# 1             1          0          3
# 2             2          0          3
# 3             0          0          3
# 4             2          0          3
# ...         ...        ...        ...
# 1454          1          0        NaN
# 1455          1          0          3
# 1456          1          0          3
# 1457          2          0        NaN
# 1458          2          0          3
#
# [2919 rows x 10 columns]

# %%
o2 = o2.astype(float)
o2.describe()
# Out:
#         Electrical    ExterCond    ExterQual  Exterior1st  Exterior2nd  \
# count  2918.000000  2919.000000  2919.000000  2918.000000  2918.000000
# mean      0.108293     2.085646     2.396711    10.752570    10.862577
# std       0.389166     0.372361     0.580293     4.087883     4.001366
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     2.000000     2.000000     8.000000     8.000000
# 50%       0.000000     2.000000     2.000000    14.000000    14.000000
# 75%       0.000000     2.000000     3.000000    14.000000    14.000000
# max       4.000000     4.000000     4.000000    16.000000    16.000000
#
#              Fence  FireplaceQu   Foundation   Functional   GarageCond
# count  2919.000000  2919.000000  2919.000000  2917.000000  2760.000000
# mean      0.397396     0.423433     1.393285     0.151868     2.970652
# std       0.862957     0.784234     0.727061     0.639820     0.236734
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     1.000000     0.000000     3.000000
# 50%       0.000000     0.000000     1.000000     0.000000     3.000000
# 75%       0.000000     1.000000     2.000000     0.000000     3.000000
# max       4.000000     4.000000     5.000000     6.000000     5.000000

# %%
o2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000277356B2E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277356B8388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277356F23C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735725508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735757A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002773578F0C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277357C2708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277357F3E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277357F9D08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735830C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735896708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000277358D18C8>]],
#       dtype=object)

# %% [markdown]
# ### 去除離峰值

# %%
std = o2.std()
mean = o2.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (Electrical    -1.059204
#  ExterCond      0.968563
#  ExterQual      0.655831
#  Exterior1st   -1.511077
#  Exterior2nd   -1.141522
#  Fence         -2.191475
#  FireplaceQu   -1.929269
#  Foundation    -0.787899
#  Functional    -1.767592
#  GarageCond     2.260450
#  dtype: float64, Electrical      1.275790
#  ExterCond       3.202729
#  ExterQual       4.137591
#  Exterior1st    23.016218
#  Exterior2nd    22.866677
#  Fence           2.986268
#  FireplaceQu     2.776135
#  Foundation      3.574470
#  Functional      2.071329
#  GarageCond      3.680855
#  dtype: float64)

# %%
cond6=((o2>ma) | (o2<mi))
cond6
# Out:
#       Electrical  ExterCond  ExterQual  Exterior1st  Exterior2nd  Fence  \
# 0          False      False      False        False        False  False
# 1          False      False      False        False        False  False
# 2          False      False      False        False        False  False
# 3          False      False      False        False        False  False
# 4          False      False      False        False        False  False
# ...          ...        ...        ...          ...          ...    ...
# 1454       False      False      False        False        False  False
# 1455       False      False      False        False        False  False
# 1456       False      False      False        False        False  False
# 1457       False      False      False        False        False  False
# 1458       False      False      False        False        False  False
#
#       FireplaceQu  Foundation  Functional  GarageCond
# 0           False       False       False       False
# 1           False       False       False       False
# 2           False       False       False       False
# 3           False       False       False       False
# 4           False       False       False       False
# ...           ...         ...         ...         ...
# 1454        False       False       False       False
# 1455        False       False       False       False
# 1456        False       False       False       False
# 1457        False       False       False       False
# 1458        False       False       False       False
#
# [2919 rows x 10 columns]

# %%
cond6.sum()
# Out:
# Electrical      59
# ExterCond       15
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# Fence          124
# FireplaceQu    120
# Foundation      16
# Functional      65
# GarageCond     106
# dtype: int64

# %%
cond6=cond6.any(axis=1)

# %%
o2[cond6]
# Out:
#       Electrical  ExterCond  ExterQual  Exterior1st  Exterior2nd  Fence  \
# 5            0.0        2.0        2.0         14.0         14.0    2.0
# 8            2.0        2.0        2.0          3.0         16.0    0.0
# 14           0.0        2.0        2.0          8.0          8.0    3.0
# 21           2.0        2.0        2.0         15.0         15.0    1.0
# 30           0.0        1.0        2.0          3.0          3.0    2.0
# ...          ...        ...        ...          ...          ...    ...
# 1428         1.0        2.0        2.0         15.0         15.0    3.0
# 1431         0.0        2.0        2.0         15.0         15.0    0.0
# 1441         0.0        2.0        3.0         14.0         14.0    0.0
# 1444         1.0        1.0        2.0          4.0         14.0    0.0
# 1450         0.0        2.0        2.0          5.0          5.0    0.0
#
#       FireplaceQu  Foundation  Functional  GarageCond
# 5             0.0         5.0         0.0         3.0
# 8             0.0         0.0         1.0         3.0
# 14            3.0         1.0         0.0         3.0
# 21            1.0         2.0         0.0         3.0
# 30            0.0         0.0         0.0         2.0
# ...           ...         ...         ...         ...
# 1428          0.0         0.0         1.0         NaN
# 1431          0.0         3.0         3.0         NaN
# 1441          0.0         5.0         0.0         3.0
# 1444          0.0         1.0         3.0         3.0
# 1450          0.0         1.0         0.0         2.0
#
# [455 rows x 10 columns]

# %%
o11_20=o2.drop(labels=o2[cond6].index)
o11_20
# Out:
#       Electrical  ExterCond  ExterQual  Exterior1st  Exterior2nd  Fence  \
# 0            0.0        2.0        3.0         14.0         14.0    0.0
# 1            0.0        2.0        2.0          8.0          8.0    0.0
# 2            0.0        2.0        3.0         14.0         14.0    0.0
# 3            0.0        2.0        2.0         15.0         16.0    0.0
# 4            0.0        2.0        3.0         14.0         14.0    0.0
# ...          ...        ...        ...          ...          ...    ...
# 1453         0.0        2.0        2.0          5.0          5.0    1.0
# 1454         0.0        2.0        2.0          5.0          5.0    0.0
# 1455         0.0        2.0        2.0          5.0          5.0    0.0
# 1456         0.0        2.0        2.0         14.0         14.0    0.0
# 1458         0.0        2.0        2.0          6.0          6.0    0.0
#
#       FireplaceQu  Foundation  Functional  GarageCond
# 0             0.0         2.0         0.0         3.0
# 1             0.0         1.0         0.0         3.0
# 2             0.0         2.0         0.0         3.0
# 3             1.0         0.0         0.0         3.0
# 4             0.0         2.0         0.0         3.0
# ...           ...         ...         ...         ...
# 1453          0.0         1.0         0.0         NaN
# 1454          0.0         1.0         0.0         NaN
# 1455          0.0         1.0         0.0         3.0
# 1456          0.0         1.0         0.0         3.0
# 1458          0.0         2.0         0.0         3.0
#
# [2071 rows x 10 columns]

# %%
o11_20.describe(),o2.describe()
# Out:
# (        Electrical    ExterCond    ExterQual  Exterior1st  Exterior2nd  \
#  count  2070.000000  2071.000000  2071.000000  2070.000000  2070.000000
#  mean      0.057488     2.088363     2.445196    10.880193    10.912077
#  std       0.232829     0.326620     0.587112     3.999655     3.944516
#  min       0.000000     1.000000     1.000000     0.000000     0.000000
#  25%       0.000000     2.000000     2.000000     8.000000     8.000000
#  50%       0.000000     2.000000     2.000000    14.000000    14.000000
#  75%       0.000000     2.000000     3.000000    14.000000    14.000000
#  max       1.000000     3.000000     4.000000    16.000000    16.000000
#
#               Fence  FireplaceQu   Foundation   Functional  GarageCond
#  count  2071.000000  2071.000000  2071.000000  2071.000000      1968.0
#  mean      0.261226     0.308547     1.450507     0.057943         3.0
#  std       0.645937     0.500164     0.671244     0.303798         0.0
#  min       0.000000     0.000000     0.000000     0.000000         3.0
#  25%       0.000000     0.000000     1.000000     0.000000         3.0
#  50%       0.000000     0.000000     2.000000     0.000000         3.0
#  75%       0.000000     1.000000     2.000000     0.000000         3.0
#  max       2.000000     2.000000     3.000000     2.000000         3.0  ,
#          Electrical    ExterCond    ExterQual  Exterior1st  Exterior2nd  \
#  count  2918.000000  2919.000000  2919.000000  2918.000000  2918.000000
#  mean      0.108293     2.085646     2.396711    10.752570    10.862577
#  std       0.389166     0.372361     0.580293     4.087883     4.001366
#  min       0.000000     0.000000     1.000000     0.000000     0.000000
#  25%       0.000000     2.000000     2.000000     8.000000     8.000000
#  50%       0.000000     2.000000     2.000000    14.000000    14.000000
#  75%       0.000000     2.000000     3.000000    14.000000    14.000000
#  max       4.000000     4.000000     4.000000    16.000000    16.000000
#
#               Fence  FireplaceQu   Foundation   Functional   GarageCond
#  count  2919.000000  2919.000000  2919.000000  2917.000000  2760.000000
#  mean      0.397396     0.423433     1.393285     0.151868     2.970652
#  std       0.862957     0.784234     0.727061     0.639820     0.236734
#  min       0.000000     0.000000     0.000000     0.000000     1.000000
#  25%       0.000000     0.000000     1.000000     0.000000     3.000000
#  50%       0.000000     0.000000     1.000000     0.000000     3.000000
#  75%       0.000000     1.000000     2.000000     0.000000     3.000000
#  max       4.000000     4.000000     5.000000     6.000000     5.000000  )

# %%
o11_20.hist(),o2.hist()
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735A7B308>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735B1F2C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735B39408>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735B70508>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735BA8608>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735BE1748>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735C187C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735C518C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735C5C4C8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735C95688>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735CFBC08>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735D33D88>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735D77FC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735EC9E88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735EFC6C8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735F357C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735F6D908>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027735FA5988>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027735FDDA88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000027736016BC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277360227C8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x00000277360599C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277360C0EC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000277360FE108>]],
#        dtype=object))

# %% [markdown]
# ### o3 object 21-30筆資料

# %%
o3 = obj.iloc[:,20:30]
o3
# Out:
#      GarageFinish GarageQual GarageType Heating HeatingQC HouseStyle  \
# 0             RFn         TA     Attchd    GasA        Ex     2Story
# 1             RFn         TA     Attchd    GasA        Ex     1Story
# 2             RFn         TA     Attchd    GasA        Ex     2Story
# 3             Unf         TA     Detchd    GasA        Gd     2Story
# 4             RFn         TA     Attchd    GasA        Ex     2Story
# ...           ...        ...        ...     ...       ...        ...
# 1454          NaN        NaN        NaN    GasA        Gd     2Story
# 1455          Unf         TA    CarPort    GasA        TA     2Story
# 1456          Unf         TA     Detchd    GasA        Ex     1Story
# 1457          NaN        NaN        NaN    GasA        TA     SFoyer
# 1458          Fin         TA     Attchd    GasA        Ex     2Story
#
#      KitchenQual LandContour LandSlope LotConfig
# 0             Gd         Lvl       Gtl    Inside
# 1             TA         Lvl       Gtl       FR2
# 2             Gd         Lvl       Gtl    Inside
# 3             Gd         Lvl       Gtl    Corner
# 4             Gd         Lvl       Gtl       FR2
# ...          ...         ...       ...       ...
# 1454          TA         Lvl       Gtl    Inside
# 1455          TA         Lvl       Gtl    Inside
# 1456          TA         Lvl       Gtl    Inside
# 1457          TA         Lvl       Gtl    Inside
# 1458          TA         Lvl       Mod    Inside
#
# [2919 rows x 10 columns]

# %%
o3.describe()
# Out:
#        GarageFinish GarageQual GarageType Heating HeatingQC HouseStyle  \
# count          2760       2760       2762    2919      2919       2919
# unique            3          5          6       6         5          8
# top             Unf         TA     Attchd    GasA        Ex     1Story
# freq           1230       2604       1723    2874      1493       1471
#
#        KitchenQual LandContour LandSlope LotConfig
# count         2918        2919      2919      2919
# unique           4           4         3         5
# top             TA         Lvl       Gtl    Inside
# freq          1492        2622      2778      2133

# %% [markdown]
# ### 改成數字

# %%
#將GarageFinish改為數值
o3.loc[o3['GarageFinish'].isnull(),'GarageFinish']=0
o3.loc[o3['GarageFinish'] =='Fin','GarageFinish']=1
o3.loc[o3['GarageFinish'] =='RFn','GarageFinish']=2
o3.loc[o3['GarageFinish'] =='Unf','GarageFinish']=3
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#將GarageQual改為數值
o3.loc[o3['GarageQual'].isnull(),'GarageQual']=0
o3.loc[o3['GarageQual'] =='Po','GarageQual']=1
o3.loc[o3['GarageQual'] =='Fa','GarageQual']=2
o3.loc[o3['GarageQual'] =='TA','GarageQual']=3
o3.loc[o3['GarageQual'] =='Gd','GarageQual']=4
o3.loc[o3['GarageQual'] =='Ex','GarageQual']=5
o3
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#      GarageFinish GarageQual GarageType Heating HeatingQC HouseStyle  \
# 0               2          3     Attchd    GasA        Ex     2Story
# 1               2          3     Attchd    GasA        Ex     1Story
# 2               2          3     Attchd    GasA        Ex     2Story
# 3               3          3     Detchd    GasA        Gd     2Story
# 4               2          3     Attchd    GasA        Ex     2Story
# ...           ...        ...        ...     ...       ...        ...
# 1454            0          0        NaN    GasA        Gd     2Story
# 1455            3          3    CarPort    GasA        TA     2Story
# 1456            3          3     Detchd    GasA        Ex     1Story
# 1457            0          0        NaN    GasA        TA     SFoyer
# 1458            1          3     Attchd    GasA        Ex     2Story
#
#      KitchenQual LandContour LandSlope LotConfig
# 0             Gd         Lvl       Gtl    Inside
# 1             TA         Lvl       Gtl       FR2
# 2             Gd         Lvl       Gtl    Inside
# 3             Gd         Lvl       Gtl    Corner
# 4             Gd         Lvl       Gtl       FR2
# ...          ...         ...       ...       ...
# 1454          TA         Lvl       Gtl    Inside
# 1455          TA         Lvl       Gtl    Inside
# 1456          TA         Lvl       Gtl    Inside
# 1457          TA         Lvl       Gtl    Inside
# 1458          TA         Lvl       Mod    Inside
#
# [2919 rows x 10 columns]
