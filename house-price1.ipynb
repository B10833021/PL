# %% [markdown]
# ### 導入train,test資料
# ### 合併資料

# %%
import pandas as pd
train = pd.read_csv(r'C:/Users/Cindy/Desktop/house-price/train.csv')
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test = pd.read_csv(r'C:/Users/Cindy/Desktop/house-price/test.csv')
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
data = pd.concat([train,test])
data
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          856       854          0   NaN             3     1Fam       TA
# 1         1262         0          0   NaN             3     1Fam       TA
# 2          920       866          0   NaN             3     1Fam       TA
# 3          961       756          0   NaN             3     1Fam       Gd
# 4         1145      1053          0   NaN             4     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# ...

# %%
data.describe()
# Out:
#           1stFlrSF     2ndFlrSF    3SsnPorch  BedroomAbvGr   BsmtFinSF1  \
# count  2919.000000  2919.000000  2919.000000   2919.000000  2918.000000
# mean   1159.581706   336.483727     2.602261      2.860226   441.423235
# std     392.362079   428.701456    25.188169      0.822693   455.610826
# min     334.000000     0.000000     0.000000      0.000000     0.000000
# 25%     876.000000     0.000000     0.000000      2.000000     0.000000
# 50%    1082.000000     0.000000     0.000000      3.000000   368.500000
# 75%    1387.500000   704.000000     0.000000      3.000000   733.000000
# max    5095.000000  2065.000000   508.000000      8.000000  5644.000000
#
#         BsmtFinSF2  BsmtFullBath  BsmtHalfBath    BsmtUnfSF  EnclosedPorch  \
# count  2918.000000   2917.000000   2917.000000  2918.000000    2919.000000
# mean     49.582248      0.429894      0.061364   560.772104      23.098321
# std     169.205611      0.524736      0.245687   439.543659      64.244246
# ...

# %% [markdown]
# ### 分出data之dtype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
# 1stFlrSF         2919 non-null int64
# 2ndFlrSF         2919 non-null int64
# 3SsnPorch        2919 non-null int64
# Alley            198 non-null object
# BedroomAbvGr     2919 non-null int64
# BldgType         2919 non-null object
# BsmtCond         2837 non-null object
# BsmtExposure     2837 non-null object
# BsmtFinSF1       2918 non-null float64
# BsmtFinSF2       2918 non-null float64
# BsmtFinType1     2840 non-null object
# BsmtFinType2     2839 non-null object
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtQual         2838 non-null object
# BsmtUnfSF        2918 non-null float64
# CentralAir       2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# Electrical       2918 non-null object
# EnclosedPorch    2919 non-null int64
# ExterCond        2919 non-null object
# ...

# %% [markdown]
# ### 處理int, float

# %%
num = data.select_dtypes(exclude=['object'])
num
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# ...

# %%
num.shape
# Out:
# (2919, 38)

# %% [markdown]
# ### df1:前10筆資料

# %%
df1 = num.iloc[:,0:10]
df1
#1stFlrSF: First Floor square feet
#2ndFlrSF: Second floor square feet
#3SsnPorch: Three season porch area in square feet
#BsmtFinSF1: Type 1 finished square feet
#BsmtFinSF2: Type 2 finished square feet
#BsmtFullBath: Basement full bathrooms
#BsmtHalfBath: Basement half bathrooms
#BsmtUnfSF: Unfinished square feet of basement area
#EnclosedPorch: Enclosed porch area in square feet
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch
# ...

# %%
df1.describe()
# Out:
#           1stFlrSF     2ndFlrSF    3SsnPorch  BedroomAbvGr   BsmtFinSF1  \
# count  2919.000000  2919.000000  2919.000000   2919.000000  2918.000000
# mean   1159.581706   336.483727     2.602261      2.860226   441.423235
# std     392.362079   428.701456    25.188169      0.822693   455.610826
# min     334.000000     0.000000     0.000000      0.000000     0.000000
# 25%     876.000000     0.000000     0.000000      2.000000     0.000000
# 50%    1082.000000     0.000000     0.000000      3.000000   368.500000
# 75%    1387.500000   704.000000     0.000000      3.000000   733.000000
# max    5095.000000  2065.000000   508.000000      8.000000  5644.000000
#
#         BsmtFinSF2  BsmtFullBath  BsmtHalfBath    BsmtUnfSF  EnclosedPorch
# count  2918.000000   2917.000000   2917.000000  2918.000000    2919.000000
# mean     49.582248      0.429894      0.061364   560.772104      23.098321
# std     169.205611      0.524736      0.245687   439.543659      64.244246
# ...

# %%
#df1 = df1.drop(labels=['3SsnPorch','BsmtFinSF2','BsmtHalfBath','EnclosedPorch'],axis='columns')
#df1

# %%
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
df1.plot()

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021032E61748>,
# ...
#       dtype=object)

# %% [markdown]
# ### df2 11-20筆資料

# %%
df2=num.iloc[:,10:20]
df2
#Fireplaces: Number of fireplaces
#FullBath: Full bathrooms above grade
#GarageArea: Size of garage in square feet
#GarageCars: Size of garage in car capacity
#GarageYrBlt: Year garage was built
#GrLivArea: Above grade (ground) living area square feet
#HalfBath: Half baths above grade
#LotArea: Lot size in square feet
# Out:
#       Fireplaces  FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  \
# 0              0         2       548.0         2.0       2003.0       1710
# 1              1         2       460.0         2.0       1976.0       1262
# 2              1         2       608.0         2.0       2001.0       1786
# 3              1         1       642.0         3.0       1998.0       1717
# 4              1         2       836.0         3.0       2000.0       2198
# ...          ...       ...         ...         ...          ...        ...
# 1454           0         1         0.0         0.0          NaN       1092
# 1455           0         1       286.0         1.0       1970.0       1092
# 1456           1         1       576.0         2.0       1960.0       1224
# 1457           0         1         0.0         0.0          NaN        970
# 1458           1         2       650.0         3.0       1993.0       2000
#
#       HalfBath    Id  KitchenAbvGr  LotArea
# ...

# %%
df2.describe()
# Out:
#         Fireplaces     FullBath   GarageArea   GarageCars  GarageYrBlt  \
# count  2919.000000  2919.000000  2918.000000  2918.000000  2760.000000
# mean      0.597122     1.568003   472.874572     1.766621  1978.113406
# std       0.646129     0.552969   215.394815     0.761624    25.574285
# min       0.000000     0.000000     0.000000     0.000000  1895.000000
# 25%       0.000000     1.000000   320.000000     1.000000  1960.000000
# 50%       1.000000     2.000000   480.000000     2.000000  1979.000000
# 75%       1.000000     2.000000   576.000000     2.000000  2002.000000
# max       4.000000     4.000000  1488.000000     5.000000  2207.000000
#
#          GrLivArea     HalfBath           Id  KitchenAbvGr        LotArea
# count  2919.000000  2919.000000  2919.000000   2919.000000    2919.000000
# mean   1500.759849     0.380267  1460.000000      1.044536   10168.114080
# std     506.051045     0.502872   842.787043      0.214462    7886.996359
# ...

# %% [markdown]
# ### df3 21-30筆資料

# %%
df3 = num.iloc[:,20:30]
df3
#LotFrontage: Linear feet of street connected to property
#LowQualFinSF: Low quality finished square feet (all floors)
#MSSubClass: Identifies the type of dwelling involved in the sale.
#MiscVal: $Value of miscellaneous feature
#MoSold: Month Sold (MM)
#OpenPorchSF: Open porch area in square feet
#OverallCond: Rates the overall condition of the house
#OverallQual: Rates the overall material and finish of the house
#PoolArea: Pool area in square feet
# Out:
#       LotFrontage  LowQualFinSF  MSSubClass  MasVnrArea  MiscVal  MoSold  \
# 0            65.0             0          60       196.0        0       2
# 1            80.0             0          20         0.0        0       5
# 2            68.0             0          60       162.0        0       9
# 3            60.0             0          70         0.0        0       2
# 4            84.0             0          60       350.0        0      12
# ...           ...           ...         ...         ...      ...     ...
# 1454         21.0             0         160         0.0        0       6
# 1455         21.0             0         160         0.0        0       4
# 1456        160.0             0          20         0.0        0       9
# 1457         62.0             0          85         0.0      700       7
# 1458         74.0             0          60        94.0        0      11
#
#       OpenPorchSF  OverallCond  OverallQual  PoolArea
# ...

# %%
df3.loc[df3['MSSubClass'] ==20,'MSSubClass']=0
df3.loc[df3['MSSubClass'] ==30,'MSSubClass']=1
df3.loc[df3['MSSubClass'] ==40,'MSSubClass']=2
df3.loc[df3['MSSubClass'] ==45,'MSSubClass']=3
df3.loc[df3['MSSubClass'] ==50,'MSSubClass']=4
df3.loc[df3['MSSubClass'] ==60,'MSSubClass']=5
df3.loc[df3['MSSubClass'] ==70,'MSSubClass']=6
df3.loc[df3['MSSubClass'] ==75,'MSSubClass']=7
df3.loc[df3['MSSubClass'] ==80,'MSSubClass']=8
df3.loc[df3['MSSubClass'] ==85,'MSSubClass']=9
df3.loc[df3['MSSubClass'] ==90,'MSSubClass']=10
df3.loc[df3['MSSubClass'] ==120,'MSSubClass']=11
df3.loc[df3['MSSubClass'] ==150,'MSSubClass']=12
df3.loc[df3['MSSubClass'] ==160,'MSSubClass']=13
df3.loc[df3['MSSubClass'] ==180,'MSSubClass']=14
df3.loc[df3['MSSubClass'] ==190,'MSSubClass']=15

# %%
df3.describe()
# Out:
#        LotFrontage  LowQualFinSF   MSSubClass   MasVnrArea       MiscVal  \
# count  2433.000000   2919.000000  2919.000000  2896.000000   2919.000000
# mean     69.305795      4.694416     4.266530   102.201312     50.825968
# std      23.344905     46.396825     4.344907   179.334253    567.402211
# min      21.000000      0.000000     0.000000     0.000000      0.000000
# 25%      59.000000      0.000000     0.000000     0.000000      0.000000
# 50%      68.000000      0.000000     4.000000     0.000000      0.000000
# 75%      80.000000      0.000000     6.000000   164.000000      0.000000
# max     313.000000   1064.000000    15.000000  1600.000000  17000.000000
#
#             MoSold  OpenPorchSF  OverallCond  OverallQual     PoolArea
# count  2919.000000  2919.000000  2919.000000  2919.000000  2919.000000
# mean      6.213087    47.486811     5.564577     6.089072     2.251799
# std       2.714762    67.575493     1.113131     1.409947    35.663946
# ...

# %%
df3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000210319FCD48>,
# ...
#       dtype=object)

# %%
#df3 = df3.drop(labels=['LowQualFinSF','MiscVal','PoolArea'],axis='columns')
#df3

# %% [markdown]
# ### df4 31-40筆資料

# %%
df4 = num.iloc[:,30:40]
df4
#ScreenPorch: Screen porch area in square feet
#TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#TotalBsmtSF: Total square feet of basement area
#WoodDeckSF: Wood deck area in square feet
#YearBuilt: Original construction date
#YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#YrSold: Year Sold (YYYY)
# Out:
#       SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0      208500.0            0             8        856.0           0
# 1      181500.0            0             6       1262.0         298
# 2      223500.0            0             6        920.0           0
# 3      140000.0            0             7        756.0           0
# 4      250000.0            0             9       1145.0         192
# ...         ...          ...           ...          ...         ...
# 1454        NaN            0             5        546.0           0
# 1455        NaN            0             6        546.0           0
# 1456        NaN            0             7       1224.0         474
# 1457        NaN            0             6        912.0          80
# 1458        NaN            0             9        996.0         190
#
#       YearBuilt  YearRemodAdd  YrSold
# 0          2003          2003    2008
# 1          1976          1976    2007
# ...

# %%
df4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021032F10888>,
# ...
#       dtype=object)

# %%
df4.describe()
# Out:
#            SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF   WoodDeckSF  \
# count    1460.000000  2919.000000   2919.000000  2918.000000  2919.000000
# mean   180921.195890    16.062350      6.451524  1051.777587    93.709832
# std     79442.502883    56.184365      1.569379   440.766258   126.526589
# min     34900.000000     0.000000      2.000000     0.000000     0.000000
# 25%    129975.000000     0.000000      5.000000   793.000000     0.000000
# 50%    163000.000000     0.000000      6.000000   989.500000     0.000000
# 75%    214000.000000     0.000000      7.000000  1302.000000   168.000000
# max    755000.000000   576.000000     15.000000  6110.000000  1424.000000
#
#          YearBuilt  YearRemodAdd       YrSold
# count  2919.000000   2919.000000  2919.000000
# mean   1971.312778   1984.264474  2007.792737
# std      30.291442     20.894344     1.314964
# min    1872.000000   1950.000000  2006.000000
# 25%    1953.500000   1965.000000  2007.000000
# ...

# %%
#df4 = df4.drop(labels = ['ScreenPorch'],axis = 'columns')

# %% [markdown]
# ### 合併數字欄位

# %%
num = pd.concat([df1,df2,df3,df4],axis=1)
num
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# ...

# %% [markdown]
# ### 處理object 資料

# %%
#obj: dtype為object
obj = data.select_dtypes(include=['object'])
obj
# Out:
#      Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0      NaN     1Fam       TA           No          GLQ          Unf       Gd
# 1      NaN     1Fam       TA           Gd          ALQ          Unf       Gd
# 2      NaN     1Fam       TA           Mn          GLQ          Unf       Gd
# 3      NaN     1Fam       Gd           No          ALQ          Unf       TA
# 4      NaN     1Fam       TA           Av          GLQ          Unf       Gd
# ...    ...      ...      ...          ...          ...          ...      ...
# 1454   NaN    Twnhs       TA           No          Unf          Unf       TA
# 1455   NaN   TwnhsE       TA           No          Rec          Unf       TA
# 1456   NaN     1Fam       TA           No          ALQ          Unf       TA
# 1457   NaN     1Fam       TA           Av          GLQ          Unf       Gd
# 1458   NaN     1Fam       TA           Av          LwQ          Unf       Gd
#
# ...

# %%
obj.describe()
# Out:
#        Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# count    198     2919     2837         2837         2840         2839
# unique     2        5        4            4            6            6
# top     Grvl     1Fam       TA           No          Unf          Unf
# freq     120     2425     2606         1904          851         2493
#
#        BsmtQual CentralAir Condition1 Condition2  ... MiscFeature  \
# count      2838       2919       2919       2919  ...         105
# unique        4          2          9          8  ...           4
# top          TA          Y       Norm       Norm  ...        Shed
# freq       1283       2723       2511       2889  ...          95
#
#        Neighborhood PavedDrive PoolQC RoofMatl RoofStyle SaleCondition  \
# count          2919       2919     10     2919      2919          2919
# unique           25          3      3        8         6             6
# ...

# %% [markdown]
# ### 處理object 1-10 筆資料

# %%
o1 = obj.iloc[:,0:10]
o1
# Out:
#      Alley BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0      NaN     1Fam       TA           No          GLQ          Unf       Gd
# 1      NaN     1Fam       TA           Gd          ALQ          Unf       Gd
# 2      NaN     1Fam       TA           Mn          GLQ          Unf       Gd
# 3      NaN     1Fam       Gd           No          ALQ          Unf       TA
# 4      NaN     1Fam       TA           Av          GLQ          Unf       Gd
# ...    ...      ...      ...          ...          ...          ...      ...
# 1454   NaN    Twnhs       TA           No          Unf          Unf       TA
# 1455   NaN   TwnhsE       TA           No          Rec          Unf       TA
# 1456   NaN     1Fam       TA           No          ALQ          Unf       TA
# 1457   NaN     1Fam       TA           Av          GLQ          Unf       Gd
# 1458   NaN     1Fam       TA           Av          LwQ          Unf       Gd
#
#      CentralAir Condition1 Condition2
# ...

# %%
#將Alley改為數值
o1.loc[o1['Alley'] =='Grvl','Alley']=0
o1.loc[o1['Alley'] =='Pave','Alley']=1
o1.loc[o1['Alley'].isnull(),'Alley']=2
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將BldgType改為數值
o1.loc[o1['BldgType'] =='1Fam','BldgType']=0
o1.loc[o1['BldgType'] =='TwnhsE','BldgType']=1
o1.loc[o1['BldgType'] =='Duplex','BldgType']=2
o1.loc[o1['BldgType'] =='Twnhs','BldgType']=3
o1.loc[o1['BldgType'] =='2fmCon','BldgType']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將BsmtCond改為數值
o1.loc[o1['BsmtCond'] =='Po','BsmtCond']=1
o1.loc[o1['BsmtCond'] =='Fa','BsmtCond']=2
o1.loc[o1['BsmtCond'] =='TA','BsmtCond']=3
o1.loc[o1['BsmtCond'] =='Gd','BsmtCond']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將BsmtExposure改為數值
o1.loc[o1['BsmtExposure'] =='NA','BsmtExposure']=0
o1.loc[o1['BsmtExposure'] =='No','BsmtExposure']=1
o1.loc[o1['BsmtExposure'] =='Mn','BsmtExposure']=2
o1.loc[o1['BsmtExposure'] =='Av','BsmtExposure']=3
o1.loc[o1['BsmtExposure'] =='Gd','BsmtExposure']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將BsmtFinType1改為數值
o1.loc[o1['BsmtFinType1'] =='NA','BsmtFinType1']=0
o1.loc[o1['BsmtFinType1'] =='Unf','BsmtFinType1']=1
o1.loc[o1['BsmtFinType1'] =='LwQ','BsmtFinType1']=2
o1.loc[o1['BsmtFinType1'] =='Rec','BsmtFinType1']=3
o1.loc[o1['BsmtFinType1'] =='BLQ','BsmtFinType1']=4
o1.loc[o1['BsmtFinType1'] =='ALQ','BsmtFinType1']=5
o1.loc[o1['BsmtFinType1'] =='GLQ','BsmtFinType1']=6
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將BsmtFinType2改為數值
o1.loc[o1['BsmtFinType2'] =='NA','BsmtFinType2']=0
o1.loc[o1['BsmtFinType2'] =='Unf','BsmtFinType2']=1
o1.loc[o1['BsmtFinType2'] =='LwQ','BsmtFinType2']=2
o1.loc[o1['BsmtFinType2'] =='Rec','BsmtFinType2']=3
o1.loc[o1['BsmtFinType2'] =='BLQ','BsmtFinType2']=4
o1.loc[o1['BsmtFinType2'] =='ALQ','BsmtFinType2']=5
o1.loc[o1['BsmtFinType2'] =='GLQ','BsmtFinType2']=6
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將BsmtQual改為數值
o1.loc[o1['BsmtQual'] =='Po','BsmtQual']=1
o1.loc[o1['BsmtQual'] =='Fa','BsmtQual']=2
o1.loc[o1['BsmtQual'] =='TA','BsmtQual']=3
o1.loc[o1['BsmtQual'] =='Gd','BsmtQual']=4
o1.loc[o1['BsmtQual'] =='Ex','BsmtQual']=5
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將CentralAir改為數值
o1.loc[o1['CentralAir'] =='N','CentralAir']=0
o1.loc[o1['CentralAir'] =='Y','CentralAir']=1
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#將Condition1改為數值
o1.loc[o1['Condition1'] =='Artery','Condition1']=0
o1.loc[o1['Condition1'] =='Feedr','Condition1']=1
o1.loc[o1['Condition1'] =='Norm','Condition1']=2
o1.loc[o1['Condition1'] =='RRNn','Condition1']=3
o1.loc[o1['Condition1'] =='RRAn','Condition1']=4
o1.loc[o1['Condition1'] =='PosN','Condition1']=5
o1.loc[o1['Condition1'] =='PosA','Condition1']=6
o1.loc[o1['Condition1'] =='RRNe','Condition1']=7
o1.loc[o1['Condition1'] =='RRAe','Condition1']=8
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Condition2改為數值
o1.loc[o1['Condition2'] =='Artery','Condition2']=0
o1.loc[o1['Condition2'] =='Feedr','Condition2']=1
o1.loc[o1['Condition2'] =='Norm','Condition2']=2
o1.loc[o1['Condition2'] =='RRNn','Condition2']=3
o1.loc[o1['Condition2'] =='RRAn','Condition2']=4
o1.loc[o1['Condition2'] =='PosN','Condition2']=5
o1.loc[o1['Condition2'] =='PosA','Condition2']=6
o1.loc[o1['Condition2'] =='RRNe','Condition2']=7
o1.loc[o1['Condition2'] =='RRAe','Condition2']=8
o1
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
o1 = o1.astype(float)
o1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002103467B208>,
# ...
#       dtype=object)

# %%
o1.astype(float).describe()
# Out:
#              Alley     BldgType     BsmtCond  BsmtExposure  BsmtFinType1  \
# count  2919.000000  2919.000000  2837.000000   2837.000000   2840.000000
# mean      1.891059     0.336074     3.002820      1.670779      3.640141
# std       0.423503     0.866186     0.294506      1.048625      2.057660
# min       0.000000     0.000000     1.000000      1.000000      1.000000
# 25%       2.000000     0.000000     3.000000      1.000000      1.000000
# 50%       2.000000     0.000000     3.000000      1.000000      4.000000
# 75%       2.000000     0.000000     3.000000      2.000000      6.000000
# max       2.000000     4.000000     4.000000      4.000000      6.000000
#
#        BsmtFinType2     BsmtQual   CentralAir   Condition1   Condition2
# count   2839.000000  2838.000000  2919.000000  2919.000000  2919.000000
# mean       1.309616     3.576815     0.932854     2.053443     2.005139
# std        0.943963     0.698645     0.250318     0.936954     0.244839
# ...

# %%
#o1 = o1.drop(labels = ['BsmtFinType2'], axis = 'columns')

# %% [markdown]
# ### o2 object 11-20筆資料

# %%
o2 = obj.iloc[:,10:20]
o2
# Out:
#      Electrical ExterCond ExterQual Exterior1st Exterior2nd  Fence  \
# 0         SBrkr        TA        Gd     VinylSd     VinylSd    NaN
# 1         SBrkr        TA        TA     MetalSd     MetalSd    NaN
# 2         SBrkr        TA        Gd     VinylSd     VinylSd    NaN
# 3         SBrkr        TA        TA     Wd Sdng     Wd Shng    NaN
# 4         SBrkr        TA        Gd     VinylSd     VinylSd    NaN
# ...         ...       ...       ...         ...         ...    ...
# 1454      SBrkr        TA        TA     CemntBd     CmentBd    NaN
# 1455      SBrkr        TA        TA     CemntBd     CmentBd    NaN
# 1456      SBrkr        TA        TA     VinylSd     VinylSd    NaN
# 1457      SBrkr        TA        TA     HdBoard     Wd Shng  MnPrv
# 1458      SBrkr        TA        TA     HdBoard     HdBoard    NaN
#
#      FireplaceQu Foundation Functional GarageCond
# 0            NaN      PConc        Typ         TA
# 1             TA     CBlock        Typ         TA
# ...

# %%
o2.describe()
# Out:
#        Electrical ExterCond ExterQual Exterior1st Exterior2nd  Fence  \
# count        2918      2919      2919        2918        2918    571
# unique          5         5         4          15          16      4
# top         SBrkr        TA        TA     VinylSd     VinylSd  MnPrv
# freq         2671      2538      1798        1025        1014    329
#
#        FireplaceQu Foundation Functional GarageCond
# count         1499       2919       2917       2760
# unique           5          6          7          5
# top             Gd      PConc        Typ         TA
# freq           744       1308       2717       2654

# %% [markdown]
# # 改成數字

# %%
#將Electrical改為數值
o2.loc[o2['Electrical'] =='SBrkr','Electrical']=0
o2.loc[o2['Electrical'] =='FuseA','Electrical']=1
o2.loc[o2['Electrical'] =='FuseF','Electrical']=2
o2.loc[o2['Electrical'] =='FuseP','Electrical']=3
o2.loc[o2['Electrical'] =='Mix','Electrical']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將ExterCond改為數值
o2.loc[o2['ExterCond'] =='Po','ExterCond']=0
o2.loc[o2['ExterCond'] =='Fa','ExterCond']=1
o2.loc[o2['ExterCond'] =='TA','ExterCond']=2
o2.loc[o2['ExterCond'] =='Gd','ExterCond']=3
o2.loc[o2['ExterCond'] =='Ex','ExterCond']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將ExterQual改為數值
o2.loc[o2['ExterQual'] =='Po','ExterQual']=0
o2.loc[o2['ExterQual'] =='Fa','ExterQual']=1
o2.loc[o2['ExterQual'] =='TA','ExterQual']=2
o2.loc[o2['ExterQual'] =='Gd','ExterQual']=3
o2.loc[o2['ExterQual'] =='Ex','ExterQual']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Exterior1st改為數值
o2.loc[o2['Exterior1st'] =='AsbShng','Exterior1st']=0
o2.loc[o2['Exterior1st'] =='AsphShn','Exterior1st']=1
o2.loc[o2['Exterior1st'] =='BrkComm','Exterior1st']=2
o2.loc[o2['Exterior1st'] =='BrkFace','Exterior1st']=3
o2.loc[o2['Exterior1st'] =='CBlock','Exterior1st']=4
o2.loc[o2['Exterior1st'] =='CemntBd','Exterior1st']=5
o2.loc[o2['Exterior1st'] =='HdBoard','Exterior1st']=6
o2.loc[o2['Exterior1st'] =='ImStucc','Exterior1st']=7
o2.loc[o2['Exterior1st'] =='MetalSd','Exterior1st']=8
o2.loc[o2['Exterior1st'] =='Other','Exterior1st']=9
o2.loc[o2['Exterior1st'] =='Plywood','Exterior1st']=10
o2.loc[o2['Exterior1st'] =='PreCast','Exterior1st']=11
o2.loc[o2['Exterior1st'] =='Stone','Exterior1st']=12
o2.loc[o2['Exterior1st'] =='Stucco','Exterior1st']=13
o2.loc[o2['Exterior1st'] =='VinylSd','Exterior1st']=14
o2.loc[o2['Exterior1st'] =='Wd Sdng','Exterior1st']=15
o2.loc[o2['Exterior1st'] =='WdShing','Exterior1st']=16
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Exterior2nd改為數值
o2.loc[o2['Exterior2nd'] =='AsbShng','Exterior2nd']=0
o2.loc[o2['Exterior2nd'] =='AsphShn','Exterior2nd']=1
o2.loc[o2['Exterior2nd'] =='Brk Cmn','Exterior2nd']=2
o2.loc[o2['Exterior2nd'] =='BrkFace','Exterior2nd']=3
o2.loc[o2['Exterior2nd'] =='CBlock','Exterior2nd']=4
o2.loc[o2['Exterior2nd'] =='CmentBd','Exterior2nd']=5
o2.loc[o2['Exterior2nd'] =='HdBoard','Exterior2nd']=6
o2.loc[o2['Exterior2nd'] =='ImStucc','Exterior2nd']=7
o2.loc[o2['Exterior2nd'] =='MetalSd','Exterior2nd']=8
o2.loc[o2['Exterior2nd'] =='Other','Exterior2nd']=9
o2.loc[o2['Exterior2nd'] =='Plywood','Exterior2nd']=10
o2.loc[o2['Exterior2nd'] =='PreCast','Exterior2nd']=11
o2.loc[o2['Exterior2nd'] =='Stone','Exterior2nd']=12
o2.loc[o2['Exterior2nd'] =='Stucco','Exterior2nd']=13
o2.loc[o2['Exterior2nd'] =='VinylSd','Exterior2nd']=14
o2.loc[o2['Exterior2nd'] =='Wd Sdng','Exterior2nd']=15
o2.loc[o2['Exterior2nd'] =='Wd Shng','Exterior2nd']=16
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Fence改為數值
o2.loc[o2['Fence'].isnull(),'Fence']=0
o2.loc[o2['Fence'] =='GdPrv','Fence']=1
o2.loc[o2['Fence'] =='MnPrv','Fence']=2
o2.loc[o2['Fence'] =='GdWo','Fence']=3
o2.loc[o2['Fence'] =='MnWw','Fence']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將FireplaceQu改為數值
o2.loc[o2['FireplaceQu'].isnull(),'FireplaceQu']=0
o2.loc[o2['FireplaceQu'] =='Gd','FireplaceQu']=1
o2.loc[o2['FireplaceQu'] =='Ex','FireplaceQu']=2
o2.loc[o2['FireplaceQu'] =='Fa','FireplaceQu']=3
o2.loc[o2['FireplaceQu'] =='Po','FireplaceQu']=4
o2.loc[o2['FireplaceQu'] =='TA','FireplaceQu']=5
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Foundation改為數值
o2.loc[o2['Foundation'] =='BrkTil','Foundation']=0
o2.loc[o2['Foundation'] =='CBlock','Foundation']=1
o2.loc[o2['Foundation'] =='PConc','Foundation']=2
o2.loc[o2['Foundation'] =='Slab','Foundation']=3
o2.loc[o2['Foundation'] =='Stone','Foundation']=4
o2.loc[o2['Foundation'] =='Wood','Foundation']=5
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Functional改為數值
o2.loc[o2['Functional'] =='Typ','Functional']=0
o2.loc[o2['Functional'] =='Min1','Functional']=1
o2.loc[o2['Functional'] =='Min2','Functional']=2
o2.loc[o2['Functional'] =='Mod','Functional']=3
o2.loc[o2['Functional'] =='Maj1','Functional']=4
o2.loc[o2['Functional'] =='Maj2','Functional']=5
o2.loc[o2['Functional'] =='Sev','Functional']=6
o2.loc[o2['Functional'] =='Sal','Functional']=7
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將GarageCond改為數值
o2.loc[o2['GarageCond'].isnull(),'GarageCond']=0
o2.loc[o2['GarageCond'] =='Po','GarageCond']=1
o2.loc[o2['GarageCond'] =='Fa','GarageCond']=2
o2.loc[o2['GarageCond'] =='TA','GarageCond']=3
o2.loc[o2['GarageCond'] =='Gd','GarageCond']=4
o2.loc[o2['GarageCond'] =='Ex','GarageCond']=5
o2
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
o2 = o2.astype(float)
o2.describe()
# Out:
#         Electrical    ExterCond    ExterQual  Exterior1st  Exterior2nd  \
# count  2918.000000  2919.000000  2919.000000  2918.000000  2918.000000
# mean      0.108293     2.085646     2.396711    10.752570    10.862577
# std       0.389166     0.372361     0.580293     4.087883     4.001366
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     2.000000     2.000000     8.000000     8.000000
# 50%       0.000000     2.000000     2.000000    14.000000    14.000000
# 75%       0.000000     2.000000     3.000000    14.000000    14.000000
# max       4.000000     4.000000     4.000000    16.000000    16.000000
#
#              Fence  FireplaceQu   Foundation   Functional   GarageCond
# count  2919.000000  2919.000000  2919.000000  2917.000000  2919.000000
# mean      0.397396     1.437479     1.393285     0.151868     2.808839
# std       0.862957     1.949178     0.727061     0.639820     0.712498
# ...

# %%
#o2 = o2.drop(labels = ['Electrical','Fence','Functional','GarageCond'], axis = 'columns')

# %%
o2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021034B0D7C8>,
# ...
#       dtype=object)

# %% [markdown]
# ### o3 object 21-30筆資料

# %%
o3 = obj.iloc[:,20:30]
o3
# Out:
#      GarageFinish GarageQual GarageType Heating HeatingQC HouseStyle  \
# 0             RFn         TA     Attchd    GasA        Ex     2Story
# 1             RFn         TA     Attchd    GasA        Ex     1Story
# 2             RFn         TA     Attchd    GasA        Ex     2Story
# 3             Unf         TA     Detchd    GasA        Gd     2Story
# 4             RFn         TA     Attchd    GasA        Ex     2Story
# ...           ...        ...        ...     ...       ...        ...
# 1454          NaN        NaN        NaN    GasA        Gd     2Story
# 1455          Unf         TA    CarPort    GasA        TA     2Story
# 1456          Unf         TA     Detchd    GasA        Ex     1Story
# 1457          NaN        NaN        NaN    GasA        TA     SFoyer
# 1458          Fin         TA     Attchd    GasA        Ex     2Story
#
#      KitchenQual LandContour LandSlope LotConfig
# 0             Gd         Lvl       Gtl    Inside
# ...

# %%
o3.describe()
# Out:
#        GarageFinish GarageQual GarageType Heating HeatingQC HouseStyle  \
# count          2760       2760       2762    2919      2919       2919
# unique            3          5          6       6         5          8
# top             Unf         TA     Attchd    GasA        Ex     1Story
# freq           1230       2604       1723    2874      1493       1471
#
#        KitchenQual LandContour LandSlope LotConfig
# count         2918        2919      2919      2919
# unique           4           4         3         5
# top             TA         Lvl       Gtl    Inside
# freq          1492        2622      2778      2133

# %% [markdown]
# ### 改成數字

# %%
#將GarageFinish改為數值
o3.loc[o3['GarageFinish'].isnull(),'GarageFinish']=0
o3.loc[o3['GarageFinish'] =='Fin','GarageFinish']=1
o3.loc[o3['GarageFinish'] =='RFn','GarageFinish']=2
o3.loc[o3['GarageFinish'] =='Unf','GarageFinish']=3
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將GarageQual改為數值
o3.loc[o3['GarageQual'].isnull(),'GarageQual']=0
o3.loc[o3['GarageQual'] =='Po','GarageQual']=1
o3.loc[o3['GarageQual'] =='Fa','GarageQual']=2
o3.loc[o3['GarageQual'] =='TA','GarageQual']=3
o3.loc[o3['GarageQual'] =='Gd','GarageQual']=4
o3.loc[o3['GarageQual'] =='Ex','GarageQual']=5
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將GarageType改為數值
o3.loc[o3['GarageType'].isnull(),'GarageType']=0
o3.loc[o3['GarageType'] =='2Types','GarageType']=1
o3.loc[o3['GarageType'] =='Attchd','GarageType']=2
o3.loc[o3['GarageType'] =='Basment','GarageType']=3
o3.loc[o3['GarageType'] =='BuiltIn','GarageType']=4
o3.loc[o3['GarageType'] =='CarPort','GarageType']=5
o3.loc[o3['GarageType'] =='Detchd','GarageType']=6
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將Heating改為數值
o3.loc[o3['Heating'].isnull(),'Heating']=0
o3.loc[o3['Heating'] =='Floor','Heating']=1
o3.loc[o3['Heating'] =='GasA','Heating']=2
o3.loc[o3['Heating'] =='GasW','Heating']=3
o3.loc[o3['Heating'] =='Grav','Heating']=4
o3.loc[o3['Heating'] =='OthW','Heating']=5
o3.loc[o3['Heating'] =='Wall','Heating']=6
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將HeatingQC改為數值
o3.loc[o3['HeatingQC'] =='Po','HeatingQC']=0
o3.loc[o3['HeatingQC'] =='Fa','HeatingQC']=1
o3.loc[o3['HeatingQC'] =='TA','HeatingQC']=2
o3.loc[o3['HeatingQC'] =='Gd','HeatingQC']=3
o3.loc[o3['HeatingQC'] =='Ex','HeatingQC']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將HouseStyle改為數值
o3.loc[o3['HouseStyle'] =='1Story','HouseStyle']=0
o3.loc[o3['HouseStyle'] =='1.5Fin','HouseStyle']=1
o3.loc[o3['HouseStyle'] =='1.5Unf','HouseStyle']=2
o3.loc[o3['HouseStyle'] =='2Story','HouseStyle']=3
o3.loc[o3['HouseStyle'] =='2.5Fin','HouseStyle']=4
o3.loc[o3['HouseStyle'] =='2.5Unf','HouseStyle']=5
o3.loc[o3['HouseStyle'] =='SFoyer','HouseStyle']=6
o3.loc[o3['HouseStyle'] =='SLvl','HouseStyle']=7
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將KitchenQual改為數值
o3.loc[o3['KitchenQual'] =='Po','KitchenQual']=0
o3.loc[o3['KitchenQual'] =='Fa','KitchenQual']=1
o3.loc[o3['KitchenQual'] =='TA','KitchenQual']=2
o3.loc[o3['KitchenQual'] =='Gd','KitchenQual']=3
o3.loc[o3['KitchenQual'] =='Ex','KitchenQual']=4
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將LandContour改為數值
o3.loc[o3['LandContour'] =='Lvl','LandContour']=0
o3.loc[o3['LandContour'] =='Bnk','LandContour']=1
o3.loc[o3['LandContour'] =='HLS','LandContour']=2
o3.loc[o3['LandContour'] =='Low','LandContour']=3
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將LandSlope改為數值
o3.loc[o3['LandSlope'] =='Gtl','LandSlope']=0
o3.loc[o3['LandSlope'] =='Mod','LandSlope']=1
o3.loc[o3['LandSlope'] =='Sev','LandSlope']=2
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#將LotConfig改為數值
o3.loc[o3['LotConfig'] =='Inside','LotConfig']=0
o3.loc[o3['LotConfig'] =='Corner','LotConfig']=1
o3.loc[o3['LotConfig'] =='CulDSac','LotConfig']=2
o3.loc[o3['LotConfig'] =='FR2','LotConfig']=3
o3.loc[o3['LotConfig'] =='FR3','LotConfig']=4
o3
# Out:
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cindy\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
o3 = o3.astype(float)
o3.describe()
# Out:
#        GarageFinish   GarageQual   GarageType      Heating    HeatingQC  \
# count   2919.000000  2919.000000  2919.000000  2919.000000  2919.000000
# mean       2.066119     2.800959     3.107229     2.025351     3.151764
# std        0.938886     0.715863     1.892541     0.245678     0.957952
# min        0.000000     0.000000     0.000000     1.000000     0.000000
# 25%        1.000000     3.000000     2.000000     2.000000     2.000000
# 50%        2.000000     3.000000     2.000000     2.000000     4.000000
# 75%        3.000000     3.000000     6.000000     2.000000     4.000000
# max        3.000000     5.000000     6.000000     6.000000     4.000000
#
#         HouseStyle  KitchenQual  LandContour    LandSlope    LotConfig
# count  2919.000000  2918.000000  2919.000000  2919.000000  2919.000000
# mean      1.546420     2.510966     0.183967     0.053786     0.402193
# std       1.963116     0.662205     0.596485     0.248750     0.770388
# ...

# %%
#o3 = o3.drop(labels = ['GarageQual','Heating','LandContour','LandSlope'], axis = 'columns')

# %%
o3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021034F66588>,
# ...
#       dtype=object)

# %% [markdown]
# ### o4 object 31-43筆資料

# %%
o4 = obj.iloc[:,30:43]
o4
# Out:
#      LotShape MSZoning MasVnrType MiscFeature Neighborhood PavedDrive PoolQC  \
# 0         Reg       RL    BrkFace         NaN      CollgCr          Y    NaN
# 1         Reg       RL       None         NaN      Veenker          Y    NaN
# 2         IR1       RL    BrkFace         NaN      CollgCr          Y    NaN
# 3         IR1       RL       None         NaN      Crawfor          Y    NaN
# 4         IR1       RL    BrkFace         NaN      NoRidge          Y    NaN
# ...       ...      ...        ...         ...          ...        ...    ...
# 1454      Reg       RM       None         NaN      MeadowV          Y    NaN
# 1455      Reg       RM       None         NaN      MeadowV          Y    NaN
# 1456      Reg       RL       None         NaN      Mitchel          Y    NaN
# 1457      Reg       RL       None        Shed      Mitchel          Y    NaN
# 1458      Reg       RL    BrkFace         NaN      Mitchel          Y    NaN
#
# ...

# %%
o4.describe()
# Out:
#        LotShape MSZoning MasVnrType MiscFeature Neighborhood PavedDrive  \
# count      2919     2915       2895         105         2919       2919
# unique        4        5          4           4           25          3
# top         Reg       RL       None        Shed        NAmes          Y
# freq       1859     2265       1742          95          443       2641
#
#        PoolQC RoofMatl RoofStyle SaleCondition SaleType Street Utilities
# count      10     2919      2919          2919     2918   2919      2917
# unique      3        8         6             6        9      2         2
# top        Ex  CompShg     Gable        Normal       WD   Pave    AllPub
# freq        4     2876      2310          2402     2525   2907      2916

# %%
o4 = o4.drop(labels = ['PoolQC'],axis = 'columns')
o4
# Out:
#      LotShape MSZoning MasVnrType MiscFeature Neighborhood PavedDrive  \
# 0         Reg       RL    BrkFace         NaN      CollgCr          Y
# 1         Reg       RL       None         NaN      Veenker          Y
# 2         IR1       RL    BrkFace         NaN      CollgCr          Y
# 3         IR1       RL       None         NaN      Crawfor          Y
# 4         IR1       RL    BrkFace         NaN      NoRidge          Y
# ...       ...      ...        ...         ...          ...        ...
# 1454      Reg       RM       None         NaN      MeadowV          Y
# 1455      Reg       RM       None         NaN      MeadowV          Y
# 1456      Reg       RL       None         NaN      Mitchel          Y
# 1457      Reg       RL       None        Shed      Mitchel          Y
# 1458      Reg       RL    BrkFace         NaN      Mitchel          Y
#
#      RoofMatl RoofStyle SaleCondition SaleType Street Utilities
# ...

# %% [markdown]
# ### 改成數字

# %%
#將LotShape改為數值
o4.loc[o4['LotShape'] =='Reg','LotShape']=0
o4.loc[o4['LotShape'] =='IR1','LotShape']=1
o4.loc[o4['LotShape'] =='IR2','LotShape']=2
o4.loc[o4['LotShape'] =='IR3','LotShape']=3

# %%
#將MSZoning改為數值
o4.loc[o4['MSZoning'] =='A','MSZoning']=0
o4.loc[o4['MSZoning'] =='C','MSZoning']=1
o4.loc[o4['MSZoning'] =='FV','MSZoning']=2
o4.loc[o4['MSZoning'] =='I','MSZoning']=3
o4.loc[o4['MSZoning'] =='RH','MSZoning']=4
o4.loc[o4['MSZoning'] =='RL','MSZoning']=5
o4.loc[o4['MSZoning'] =='RP','MSZoning']=6
o4.loc[o4['MSZoning'] =='RM','MSZoning']=7
o4.loc[o4['MSZoning'] =='C (all)','MSZoning']=7

# %%
#將MasVnrType改為數值
o4.loc[o4['MasVnrType'] =='BrkCmn','MasVnrType']=0
o4.loc[o4['MasVnrType'] =='BrkFace','MasVnrType']=1
o4.loc[o4['MasVnrType'] =='CBlock','MasVnrType']=2
o4.loc[o4['MasVnrType'] =='None','MasVnrType']=3
o4.loc[o4['MasVnrType'] =='Stone','MasVnrType']=4

# %%
#將MiscFeature改為數值
o4.loc[o4['MiscFeature'].isnull(),'MiscFeature']=0
o4.loc[o4['MiscFeature'] =='Elev','MiscFeature']=1
o4.loc[o4['MiscFeature'] =='Gar2','MiscFeature']=2
o4.loc[o4['MiscFeature'] =='Othr','MiscFeature']=3
o4.loc[o4['MiscFeature'] =='Shed','MiscFeature']=4
o4.loc[o4['MiscFeature'] =='TenC','MiscFeature']=5

# %%
#將Neighborhood改為數值
o4.loc[o4['Neighborhood'] =='Blmngtn','Neighborhood']=0
o4.loc[o4['Neighborhood'] =='Blueste','Neighborhood']=1
o4.loc[o4['Neighborhood'] =='BrDale','Neighborhood']=2
o4.loc[o4['Neighborhood'] =='BrkSide','Neighborhood']=3
o4.loc[o4['Neighborhood'] =='ClearCr','Neighborhood']=4
o4.loc[o4['Neighborhood'] =='CollgCr','Neighborhood']=5
o4.loc[o4['Neighborhood'] =='Crawfor','Neighborhood']=6
o4.loc[o4['Neighborhood'] =='Edwards','Neighborhood']=7
o4.loc[o4['Neighborhood'] =='Gilbert','Neighborhood']=8
o4.loc[o4['Neighborhood'] =='IDOTRR','Neighborhood']=9
o4.loc[o4['Neighborhood'] =='MeadowV','Neighborhood']=10
o4.loc[o4['Neighborhood'] =='Mitchel','Neighborhood']=11
o4.loc[o4['Neighborhood'] =='NAmes','Neighborhood']=12
o4.loc[o4['Neighborhood'] =='NoRidge','Neighborhood']=13
o4.loc[o4['Neighborhood'] =='NPkVill','Neighborhood']=14
o4.loc[o4['Neighborhood'] =='NridgHt','Neighborhood']=15
o4.loc[o4['Neighborhood'] =='NWAmes','Neighborhood']=16
o4.loc[o4['Neighborhood'] =='OldTown','Neighborhood']=17
o4.loc[o4['Neighborhood'] =='SWISU','Neighborhood']=18
o4.loc[o4['Neighborhood'] =='Sawyer','Neighborhood']=19
o4.loc[o4['Neighborhood'] =='SawyerW','Neighborhood']=20
o4.loc[o4['Neighborhood'] =='Somerst','Neighborhood']=21
o4.loc[o4['Neighborhood'] =='StoneBr','Neighborhood']=22
o4.loc[o4['Neighborhood'] =='Timber','Neighborhood']=23
o4.loc[o4['Neighborhood'] =='Veenker','Neighborhood']=24

# %%
#將PavedDrive改為數值
o4.loc[o4['PavedDrive'] =='Y','PavedDrive']=0
o4.loc[o4['PavedDrive'] =='P','PavedDrive']=1
o4.loc[o4['PavedDrive'] =='N','PavedDrive']=2

# %%
#將PoolQC改為數值
#o4.loc[o4['PoolQC'].isnull(),'PoolQC']=0
#o4.loc[o4['PoolQC'] =='Po','PoolQC']=1
#o4.loc[o4['PoolQC'] =='Fa','PoolQC']=2
#o4.loc[o4['PoolQC'] =='TA','PoolQC']=3
#o4.loc[o4['PoolQC'] =='Gd','PoolQC']=4
#o4.loc[o4['PoolQC'] =='Ex','PoolQC']=5

# %%
#將RoofMatl改為數值
o4.loc[o4['RoofMatl'] =='ClyTile','RoofMatl']=0
o4.loc[o4['RoofMatl'] =='CompShg','RoofMatl']=1
o4.loc[o4['RoofMatl'] =='Membran','RoofMatl']=2
o4.loc[o4['RoofMatl'] =='Metal','RoofMatl']=3
o4.loc[o4['RoofMatl'] =='Roll','RoofMatl']=4
o4.loc[o4['RoofMatl'] =='Tar&Grv','RoofMatl']=5
o4.loc[o4['RoofMatl'] =='WdShake','RoofMatl']=6
o4.loc[o4['RoofMatl'] =='WdShngl','RoofMatl']=7

# %%
#將RoofStyle改為數值
o4.loc[o4['RoofStyle'] =='Flat','RoofStyle']=0
o4.loc[o4['RoofStyle'] =='Gable','RoofStyle']=1
o4.loc[o4['RoofStyle'] =='Gambrel','RoofStyle']=2
o4.loc[o4['RoofStyle'] =='Hip','RoofStyle']=3
o4.loc[o4['RoofStyle'] =='Mansard','RoofStyle']=4
o4.loc[o4['RoofStyle'] =='Tar&Shed','RoofStyle']=5
o4.loc[o4['RoofStyle'] =='Shed','RoofStyle']=6

# %%
#將SaleCondition改為數值
o4.loc[o4['SaleCondition'] =='Normal','SaleCondition']=0
o4.loc[o4['SaleCondition'] =='Abnorml','SaleCondition']=1
o4.loc[o4['SaleCondition'] =='AdjLand','SaleCondition']=2
o4.loc[o4['SaleCondition'] =='Alloca','SaleCondition']=3
o4.loc[o4['SaleCondition'] =='Family','SaleCondition']=4
o4.loc[o4['SaleCondition'] =='Partial','SaleCondition']=5

# %%
#將SaleType改為數值
o4.loc[o4['SaleType'].isnull(),'SaleType']=0
o4.loc[o4['SaleType'] =='CWD','SaleType']=1
o4.loc[o4['SaleType'] =='VWD','SaleType']=2
o4.loc[o4['SaleType'] =='New','SaleType']=3
o4.loc[o4['SaleType'] =='COD','SaleType']=4
o4.loc[o4['SaleType'] =='Con','SaleType']=5
o4.loc[o4['SaleType'] =='ConLw','SaleType']=6
o4.loc[o4['SaleType'] =='ConLI','SaleType']=7
o4.loc[o4['SaleType'] =='ConLD','SaleType']=8
o4.loc[o4['SaleType'] =='Oth','SaleType']=9
o4.loc[o4['SaleType'] =='WD','SaleType']=10

# %%
#將Street改為數值
o4.loc[o4['Street'] =='Grvl','Street']=0
o4.loc[o4['Street'] =='Pave','Street']=1

# %%
#將Utilities改為數值
o4.loc[o4['Utilities'] =='AllPub','Utilities']=0
o4.loc[o4['Utilities'] =='NoSewr','Utilities']=1
o4.loc[o4['Utilities'] =='NoSeWa','Utilities']=2
o4.loc[o4['Utilities'] =='ELO','Utilities']=3
o4
# Out:
#      LotShape MSZoning MasVnrType MiscFeature Neighborhood PavedDrive  \
# 0           0        5          1           0            5          0
# 1           0        5          3           0           24          0
# 2           1        5          1           0            5          0
# 3           1        5          3           0            6          0
# 4           1        5          1           0           13          0
# ...       ...      ...        ...         ...          ...        ...
# 1454        0        7          3           0           10          0
# 1455        0        7          3           0           10          0
# 1456        0        5          3           0           11          0
# 1457        0        5          3           4           11          0
# 1458        0        5          1           0           11          0
#
#      RoofMatl RoofStyle SaleCondition SaleType Street Utilities
# ...

# %%
o4.astype(float).describe()
# Out:
#           LotShape     MSZoning   MasVnrType  MiscFeature  Neighborhood  \
# count  2919.000000  2915.000000  2895.000000  2919.000000   2919.000000
# mean      0.400137     5.180789     2.452850     0.139431     12.429257
# std       0.570175     1.035029     1.038864     0.727472      5.956006
# min       0.000000     2.000000     0.000000     0.000000      0.000000
# 25%       0.000000     5.000000     1.000000     0.000000      7.000000
# 50%       0.000000     5.000000     3.000000     0.000000     12.000000
# 75%       1.000000     5.000000     3.000000     0.000000     17.000000
# max       3.000000     7.000000     4.000000     5.000000     24.000000
#
#         PavedDrive     RoofMatl    RoofStyle  SaleCondition     SaleType  \
# count  2919.000000  2919.000000  2919.000000    2919.000000  2919.000000
# mean      0.169236     1.063035     1.398082       0.580678     9.158616
# std       0.537299     0.539210     0.829426       1.472940     2.213235
# ...

# %%
#o4 = o4.drop(labels = ['MSZoning','MiscFeature','PavedDrive','RoofMatl','RoofStyle','SaleCondition','SaleType','Utilities','Street'], axis = 'columns')

# %%
o4 = o4.astype(float)
o4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000210353DB848>,
# ...
#       dtype=object)

# %% [markdown]
# ### 合併object欄位

# %%
ob = pd.concat([o1,o2,o3,o4],axis=1)
ob
# Out:
#       Alley  BldgType  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 0       2.0       0.0       3.0           1.0           6.0           1.0
# 1       2.0       0.0       3.0           4.0           5.0           1.0
# 2       2.0       0.0       3.0           2.0           6.0           1.0
# 3       2.0       0.0       4.0           1.0           5.0           1.0
# 4       2.0       0.0       3.0           3.0           6.0           1.0
# ...     ...       ...       ...           ...           ...           ...
# 1454    2.0       3.0       3.0           1.0           1.0           1.0
# 1455    2.0       1.0       3.0           1.0           3.0           1.0
# 1456    2.0       0.0       3.0           1.0           5.0           1.0
# 1457    2.0       0.0       3.0           3.0           6.0           1.0
# 1458    2.0       0.0       3.0           3.0           2.0           1.0
#
#       BsmtQual  CentralAir  Condition1  Condition2  ...  MasVnrType  \
# ...

# %%
ob.describe()
# Out:
#              Alley     BldgType     BsmtCond  BsmtExposure  BsmtFinType1  \
# count  2919.000000  2919.000000  2837.000000   2837.000000   2840.000000
# mean      1.891059     0.336074     3.002820      1.670779      3.640141
# std       0.423503     0.866186     0.294506      1.048625      2.057660
# min       0.000000     0.000000     1.000000      1.000000      1.000000
# 25%       2.000000     0.000000     3.000000      1.000000      1.000000
# 50%       2.000000     0.000000     3.000000      1.000000      4.000000
# 75%       2.000000     0.000000     3.000000      2.000000      6.000000
# max       2.000000     4.000000     4.000000      4.000000      6.000000
#
#        BsmtFinType2     BsmtQual   CentralAir   Condition1   Condition2  ...  \
# count   2839.000000  2838.000000  2919.000000  2919.000000  2919.000000  ...
# mean       1.309616     3.576815     0.932854     2.053443     2.005139  ...
# std        0.943963     0.698645     0.250318     0.936954     0.244839  ...
# ...

# %% [markdown]
# ### 合併數字與object欄位

# %%
dataset = pd.concat([num,ob],axis=1)
dataset
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  MasVnrType  \
# ...

# %% [markdown]
# ### 合併一些欄位（Ex.Gd.TA...）

# %%
dataset['new_column'] = dataset['ExterQual']+dataset['ExterCond']+dataset['BsmtQual']+dataset['BsmtCond']+dataset['HeatingQC']+dataset['KitchenQual']+dataset['FireplaceQu']+dataset['GarageQual']+dataset['GarageCond']
dataset = dataset.drop(labels = ['ExterQual','ExterCond','BsmtQual','BsmtCond','HeatingQC','KitchenQual','FireplaceQu','GarageQual','GarageCond'],axis = 'columns')
dataset
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3       706.0         0.0
# 1         1262         0          0             3       978.0         0.0
# 2          920       866          0             3       486.0         0.0
# 3          961       756          0             3       216.0         0.0
# 4         1145      1053          0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  MiscFeature  \
# ...

# %% [markdown]
# ### 把SalePrice放到最後一行

# %%
e = dataset['SalePrice']
dataset = dataset.drop(labels = 'SalePrice',axis=1)
dataset['SalePrice'] = e
dataset = dataset.sort_values(by=['SalePrice'])
dataset
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 495        720         0          0             2       495.0         0.0
# 916        480         0          0             1        50.0         0.0
# 968        600       368          0             2         0.0         0.0
# 533        334         0          0             1         0.0         0.0
# 30         649       668          0             3         0.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  Neighborhood  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 495 to 1458
# Data columns (total 72 columns):
# 1stFlrSF         2919 non-null int64
# 2ndFlrSF         2919 non-null int64
# 3SsnPorch        2919 non-null int64
# BedroomAbvGr     2919 non-null int64
# BsmtFinSF1       2918 non-null float64
# BsmtFinSF2       2918 non-null float64
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtUnfSF        2918 non-null float64
# EnclosedPorch    2919 non-null int64
# Fireplaces       2919 non-null int64
# FullBath         2919 non-null int64
# GarageArea       2918 non-null float64
# GarageCars       2918 non-null float64
# GarageYrBlt      2760 non-null float64
# GrLivArea        2919 non-null int64
# HalfBath         2919 non-null int64
# Id               2919 non-null int64
# KitchenAbvGr     2919 non-null int64
# LotArea          2919 non-null int64
# LotFrontage      2433 non-null float64
# LowQualFinSF     2919 non-null int64
# ...

# %%
new_train = dataset.iloc[0:1460,:]
new_train
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 495        720         0          0             2       495.0         0.0
# 916        480         0          0             1        50.0         0.0
# 968        600       368          0             2         0.0         0.0
# 533        334         0          0             1         0.0         0.0
# 30         649       668          0             3         0.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 803       1734      1088          0             4         0.0         0.0
# 898       2364         0          0             2      2188.0         0.0
# 1169      1831      1796          0             4      1387.0         0.0
# 1182      2411      2065          0             4      2096.0         0.0
# 691       2444      1872          0             4      1455.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  Neighborhood  \
# ...

# %%
new_test = dataset.iloc[1460:2919,:]
new_test
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          896         0          0             2       468.0       144.0
# 1         1329         0          0             3       923.0         0.0
# 2          928       701          0             3       791.0         0.0
# 3          926       678          0             3       602.0         0.0
# 4         1280         0          0             2       263.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  Neighborhood  \
# ...

# %% [markdown]
# ### 去除離峰值

# %%
std = new_train.std()
mean = new_train.mean()
mi = mean - std*3
ma = mean + std*3
mi,ma
# Out:
# (1stFlrSF            2.863498
#  2ndFlrSF         -962.592842
#  3SsnPorch         -84.542403
#  BedroomAbvGr        0.419104
#  BsmtFinSF1       -924.654546
#                      ...
#  SaleType            2.571770
#  Street              0.803902
#  Utilities          -0.155657
#  new_column         12.178826
#  SalePrice      -57406.312758
#  Length: 72, dtype: float64, 1stFlrSF          2322.389926
#  2ndFlrSF          1656.577773
#  3SsnPorch           91.361581
#  BedroomAbvGr         5.313772
#  BsmtFinSF1        1811.933999
#                      ...
#  SaleType            15.765217
#  Street               1.187879
#  Utilities            0.158397
#  new_column          35.670788
#  SalePrice       419248.704539
#  Length: 72, dtype: float64)

# %%
cond=((new_train>ma) | (new_train<mi))
cond
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 495      False     False      False         False       False       False
# 916      False     False      False         False       False       False
# 968      False     False      False         False       False       False
# 533      False     False      False         False       False       False
# 30       False     False      False         False       False       False
# ...        ...       ...        ...           ...         ...         ...
# 803      False     False      False         False       False       False
# 898       True     False      False         False        True       False
# 1169     False      True      False         False       False       False
# 1182      True      True      False         False        True       False
# 691       True      True      False         False       False       False
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  Neighborhood  \
# ...

# %%
cond.sum()
# Out:
# 1stFlrSF        12
# 2ndFlrSF         4
# 3SsnPorch       23
# BedroomAbvGr    14
# BsmtFinSF1       6
#                 ..
# SaleType         4
# Street           6
# Utilities        1
# new_column       5
# SalePrice       22
# Length: 72, dtype: int64

# %%
cond = cond.any(axis=1)
cond
# Out:
# 495     True
# 916     True
# 968     True
# 533     True
# 30      True
#         ...
# 803     True
# 898     True
# 1169    True
# 1182    True
# 691     True
# Length: 1460, dtype: bool

# %%
# ~ 顯示cond以外的資料 
d = new_train[~cond]
d
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 874        676       455          0             3         0.0         0.0
# 1279       698       430          0             2         0.0         0.0
# 935        747         0          0             1         0.0         0.0
# 1039       630         0          0             1       509.0         0.0
# 68         747         0          0             2         0.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1388      1746         0          0             3      1320.0         0.0
# 112       1282      1414          0             4       984.0         0.0
# 688       1419         0          0             2       945.0         0.0
# 987       1940         0          0             3      1646.0         0.0
# 515       2020         0          0             3      1436.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  Neighborhood  \
# ...

# %%
d.describe()
# Out:
#           1stFlrSF     2ndFlrSF   3SsnPorch  BedroomAbvGr   BsmtFinSF1  \
# count   674.000000   674.000000  674.000000    674.000000   674.000000
# mean   1151.146884   299.473294    0.034125      2.807122   452.272997
# std     324.483337   414.077847    0.885927      0.675319   410.548167
# min     483.000000     0.000000    0.000000      1.000000     0.000000
# 25%     894.500000     0.000000    0.000000      2.000000     0.000000
# 50%    1094.500000     0.000000    0.000000      3.000000   444.500000
# 75%    1368.000000   702.000000    0.000000      3.000000   733.000000
# max    2158.000000  1427.000000   23.000000      5.000000  1646.000000
#
#        BsmtFinSF2  BsmtFullBath  BsmtHalfBath    BsmtUnfSF  EnclosedPorch  \
# count  674.000000    674.000000         674.0   674.000000     674.000000
# mean    14.195846      0.430267           0.0   610.982196      11.136499
# std     64.013745      0.495481           0.0   441.122811      38.610553
# ...

# %% [markdown]
# ### 刪除資料過少的欄位

# %%
d = d.drop(labels = ['Alley'], axis = 'columns')
new_test = new_test.drop(labels = ['Alley'], axis = 'columns')

# %%
new_test.isnull().any()
# Out:
# 1stFlrSF        False
# 2ndFlrSF        False
# 3SsnPorch       False
# BedroomAbvGr    False
# BsmtFinSF1       True
#                 ...
# SaleType        False
# Street          False
# Utilities        True
# new_column       True
# SalePrice        True
# Length: 71, dtype: bool

# %% [markdown]
# ### 資料標準化

# %%
from sklearn import preprocessing
#建立StandardScaler物件
#zscore = preprocessing.StandardScaler()
# 資料標準化
#dataset = zscore.fit_transform(d)
#d = pd.DataFrame(dataset)
#d

# %%
from IPython.display import Math

# %%
Math(r'x^{(i)}_{norm}=\frac{x^{(i)}-x_{min}}{x_{max}-x_{min}}')
# Out:
# $\displaystyle x^{(i)}_{norm}=\frac{x^{(i)}-x_{min}}{x_{max}-x_{min}}$

# %% [markdown]
# ### test缺失值以中位數代替

# %%
#缺失值以中位數代替
new_test = new_test.fillna(new_test.median())
new_test
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          896         0          0             2       468.0       144.0
# 1         1329         0          0             3       923.0         0.0
# 2          928       701          0             3       791.0         0.0
# 3          926       678          0             3       602.0         0.0
# 4         1280         0          0             2       263.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1454       546       546          0             3         0.0         0.0
# 1455       546       546          0             3       252.0         0.0
# 1456      1224         0          0             4      1224.0         0.0
# 1457       970         0          0             3       337.0         0.0
# 1458       996      1004          0             3       758.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  Neighborhood  \
# ...

# %% [markdown]
# ### 熱力圖

# %%
import seaborn as sns

# %%
#計算相關係數
train_corr = d.corr()
print(train_corr.shape)
# Out:
# (71, 71)

# %%
plt.subplots(figsize=(30,10))
sns.heatmap(train_corr,annot=True,vmax=1,cmap='Blues')

# %% [markdown]
# ### 藉由熱力圖找出相關係數較高的欄位

# %%
#相關係數大於0.6的欄位
corr = train_corr.index[abs(train_corr['SalePrice'])>0.6]
corr
# Out:
# Index(['FullBath', 'GarageArea', 'GarageCars', 'GrLivArea', 'OverallQual',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'YearBuilt', 'new_column', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### 丟入隨機森林模型

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
#建立一個隨機森林的模型clf
clf = RandomForestRegressor(n_estimators=10)

# %%
#用 RandomForestRegressor 預測 SalePrice
X_train = d[corr].drop(labels = ['SalePrice'],axis = 'columns')
y_train = d['SalePrice']
X_test =  new_test[corr].drop(labels = ['SalePrice'],axis = 'columns')
y_test =  new_test.loc[new_test['SalePrice'].isnull(),'SalePrice']=''

# %%
#放進模型內訓練
clf.fit(X_train.fillna(X_train.median()).astype(int),y_train.fillna(d['SalePrice'].median()).astype(int))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 0 to 1458
# Data columns (total 9 columns):
# FullBath        1459 non-null int64
# GarageArea      1459 non-null float64
# GarageCars      1459 non-null float64
# GrLivArea       1459 non-null int64
# OverallQual     1459 non-null int64
# TotRmsAbvGrd    1459 non-null int64
# TotalBsmtSF     1459 non-null float64
# YearBuilt       1459 non-null int64
# new_column      1459 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 114.0 KB

# %%
#predict 使用模型進行預測
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([136610. , 149275. , 173920. , ..., 151150. , 104470. , 246701.3])

# %%
#顯示預測值
df = pd.DataFrame({'Id': new_test['Id'], 'Predicted': y_pred})
df = df.sort_values(by=['Id'])
df
# Out:
#         Id  Predicted
# 0     1461   136610.0
# 1     1462   149275.0
# 2     1463   173920.0
# 3     1464   186848.5
# 4     1465   198900.0
# ...    ...        ...
# 1454  2915    85400.0
# 1455  2916    87700.0
# 1456  2917   151150.0
# 1457  2918   104470.0
# 1458  2919   246701.3
#
# [1459 rows x 2 columns]

# %%
ans = pd.read_csv(r'C:/Users/Cindy/Desktop/house-price/sample_submission.csv')

# %%
#比較正確、預測值
a=ans.merge(df)
a
# Out:
#         Id    SalePrice  Predicted
# 0     1461  169277.0525   136610.0
# 1     1462  187758.3940   149275.0
# 2     1463  183583.6836   173920.0
# 3     1464  179317.4775   186848.5
# 4     1465  150730.0800   198900.0
# ...    ...          ...        ...
# 1454  2915  167081.2209    85400.0
# 1455  2916  164788.7782    87700.0
# 1456  2917  219222.4234   151150.0
# 1457  2918  184924.2797   104470.0
# 1458  2919  187741.8667   246701.3
#
# [1459 rows x 3 columns]

# %%
b=a[abs(a.iloc[:,1] - a.iloc[:,2])>1000]
b
# Out:
#         Id    SalePrice  Predicted
# 0     1461  169277.0525   136610.0
# 1     1462  187758.3940   149275.0
# 2     1463  183583.6836   173920.0
# 3     1464  179317.4775   186848.5
# 4     1465  150730.0800   198900.0
# ...    ...          ...        ...
# 1454  2915  167081.2209    85400.0
# 1455  2916  164788.7782    87700.0
# 1456  2917  219222.4234   151150.0
# 1457  2918  184924.2797   104470.0
# 1458  2919  187741.8667   246701.3
#
# [1444 rows x 3 columns]

# %%
accuracy_score(a['SalePrice'].astype(int),a['Predicted'].astype(int))
# Out:
# 0.0

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from math import sqrt

# 平均絕對誤差(MAE)、均方誤差(MSE)、均方根誤差(RMSE)
print('Mean Absolute Error:', metrics.mean_absolute_error(a['SalePrice'], a['Predicted']))  
print('Mean Squared Error:', metrics.mean_squared_error(a['SalePrice'], a['Predicted']))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(a['SalePrice'], a['Predicted'])))
# Out:
# Mean Absolute Error: 49473.08706451909
# Mean Squared Error: 3821440573.8173585
# Root Mean Squared Error: 61817.80143144334

# %% [markdown]
# ### 丟入線性回歸模型

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
#用 LinearRegression 預測 SalePrice
X_train = d[corr].drop(labels = ['SalePrice'],axis = 'columns')
y_train = d['SalePrice']
X_test =  new_test[corr].drop(labels = ['SalePrice'],axis = 'columns')
y_test =  new_test.loc[new_test['SalePrice'].isnull(),'SalePrice']=''

# %%
#放進模型內訓練
clf.fit(X_train.fillna(X_train.median()).astype(int),y_train.fillna(d['SalePrice'].median()).astype(int))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
#predict 使用模型進行預測
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([121940., 153400., 180090., ..., 134480.,  94430., 223350.])

# %%
#顯示預測值
df = pd.DataFrame({
    'Id': new_test['Id'], 'Predicted': y_pred})
df = df.sort_values(by=['Id'])
df
# Out:
#         Id  Predicted
# 0     1461   121940.0
# 1     1462   153400.0
# 2     1463   180090.0
# 3     1464   183450.0
# 4     1465   219000.0
# ...    ...        ...
# 1454  2915    86400.0
# 1455  2916    87250.0
# 1456  2917   134480.0
# 1457  2918    94430.0
# 1458  2919   223350.0
#
# [1459 rows x 2 columns]

# %%
ans = pd.read_csv(r'C:/Users/Cindy/Desktop/house-price/sample_submission.csv')

# %%
#比較正確、預測值
a=ans.merge(df)
a
# Out:
#         Id    SalePrice  Predicted
# 0     1461  169277.0525   121940.0
# 1     1462  187758.3940   153400.0
# 2     1463  183583.6836   180090.0
# 3     1464  179317.4775   183450.0
# 4     1465  150730.0800   219000.0
# ...    ...          ...        ...
# 1454  2915  167081.2209    86400.0
# 1455  2916  164788.7782    87250.0
# 1456  2917  219222.4234   134480.0
# 1457  2918  184924.2797    94430.0
# 1458  2919  187741.8667   223350.0
#
# [1459 rows x 3 columns]

# %%
b=a[abs(a.iloc[:,1] - a.iloc[:,2])>1000]
b
# Out:
#         Id    SalePrice  Predicted
# 0     1461  169277.0525   121940.0
# 1     1462  187758.3940   153400.0
# 2     1463  183583.6836   180090.0
# 3     1464  179317.4775   183450.0
# 4     1465  150730.0800   219000.0
# ...    ...          ...        ...
# 1454  2915  167081.2209    86400.0
# 1455  2916  164788.7782    87250.0
# 1456  2917  219222.4234   134480.0
# 1457  2918  184924.2797    94430.0
# 1458  2919  187741.8667   223350.0
#
# [1441 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from math import sqrt

# 平均絕對誤差(MAE)、均方誤差(MSE)、均方根誤差(RMSE)
print('Mean Absolute Error:', metrics.mean_absolute_error(a['SalePrice'], a['Predicted']))  
print('Mean Squared Error:', metrics.mean_squared_error(a['SalePrice'], a['Predicted']))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(a['SalePrice'], a['Predicted'])))
print('Accuracy_score:',accuracy_score(a['SalePrice'].astype(int),a['Predicted'].astype(int)))
# Out:
# Mean Absolute Error: 48295.3721993146
# Mean Squared Error: 3597602072.4776387
# Root Mean Squared Error: 59980.013941959354
# Accuracy_score: 0.0

# %% [markdown]
# ### 丟入svc

# %%
from sklearn.svm import SVC
X_train = d[corr].drop(labels = ['SalePrice'],axis = 'columns')
y_train = d['SalePrice']
X_test =  new_test[corr].drop(labels = ['SalePrice'],axis = 'columns')
y_test =  new_test.loc[new_test['SalePrice'].isnull(),'SalePrice']=''

# %%
#定義分類器
from sklearn import svm
predictor = svm.SVC(gamma='scale', C=1.0, decision_function_shape='ovr', kernel='rbf')
#進行分類
predictor.fit(X_train.fillna(X_train.median()).astype(int),y_train.fillna(d['SalePrice'].median()).astype(int))
y_pred=predictor.predict(X_test)

#顯示實際值和預測值
#顯示預測值
df = pd.DataFrame({'Id': new_test['Id'], 'Predicted': y_pred})
df = df.sort_values(by=['Id'])
df
# Out:
#         Id  Predicted
# 0     1461     140000
# 1     1462     140000
# 2     1463     140000
# 3     1464     140000
# 4     1465     140000
# ...    ...        ...
# 1454  2915     140000
# 1455  2916     140000
# 1456  2917     140000
# 1457  2918     140000
# 1458  2919     140000
#
# [1459 rows x 2 columns]

# %%
#比較正確、預測值
a=ans.merge(df)
a
# Out:
#         Id    SalePrice  Predicted
# 0     1461  169277.0525     140000
# 1     1462  187758.3940     140000
# 2     1463  183583.6836     140000
# 3     1464  179317.4775     140000
# 4     1465  150730.0800     140000
# ...    ...          ...        ...
# 1454  2915  167081.2209     140000
# 1455  2916  164788.7782     140000
# 1456  2917  219222.4234     140000
# 1457  2918  184924.2797     140000
# 1458  2919  187741.8667     140000
#
# [1459 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from math import sqrt

# 平均絕對誤差(MAE)、均方誤差(MSE)、均方根誤差(RMSE)
print('Mean Absolute Error:', metrics.mean_absolute_error(a['SalePrice'], a['Predicted']))  
print('Mean Squared Error:', metrics.mean_squared_error(a['SalePrice'], a['Predicted']))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(a['SalePrice'], a['Predicted'])))
print('Accuracy_score:',accuracy_score(a['SalePrice'].astype(int),a['Predicted'].astype(int)))
# Out:
# Mean Absolute Error: 36239.13361480466
# Mean Squared Error: 1559652903.7698495
# Root Mean Squared Error: 39492.44109661809
# Accuracy_score: 0.0
